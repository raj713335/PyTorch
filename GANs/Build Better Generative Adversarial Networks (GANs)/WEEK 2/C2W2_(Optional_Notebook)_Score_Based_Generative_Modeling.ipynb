# %% [markdown]
# # Score-Based Generative Modeling
#
# *Please note that this is an optional notebook meant to introduce more advanced concepts. If you’re up for a challenge, take a look and don’t worry if you can’t follow everything. There is no code to implement—only some cool code for you to learn and run!*
#
# ### Goals
# This is a hitchhiker's guide to score-based generative models, a family of approaches based on [estimating gradients of the data distribution](https://arxiv.org/abs/1907.05600). They have obtained high-quality samples comparable to GANs (like below, figure from [this paper](https://arxiv.org/abs/2006.09011)) without requiring adversarial training, and are considered by some to be [the new contender to GANs](https://ajolicoeur.wordpress.com/the-new-contender-to-gans-score-matching-with-langevin-sampling/).
#
# ![ncsnv2](https://github.com/ermongroup/ncsnv2/blob/master/assets/samples.jpg?raw=true)

# %% [markdown]
# ## Introduction
#
# ### Score and Score-Based Models
# Given a probablity density function $p(\mathbf{x})$, we define the *score* as $$\nabla_\mathbf{x} \log p(\mathbf{x}).$$ As you might guess, score-based generative models are trained to estimate $\nabla_\mathbf{x} \log p(\mathbf{x})$. Unlike likelihood-based models such as flow models or autoregressive models, score-based models do not have to be normalized and are easier to parameterize. For example, consider a non-normalized statistical model $p_\theta(\mathbf{x}) = \frac{e^{-E_\theta(\mathbf{x})}}{Z_\theta}$, where $E_\theta(\mathbf{x}) \in \mathbb{R}$ is called the energy function and $Z_\theta$ is an unknown normalizing constant that makes $p_\theta(\mathbf{x})$ a proper probability density function. The energy function is typically parameterized by a flexible neural network. When training it as a likelihood model, we need to know the normalizing constant $Z_\theta$ by computing complex high-dimensional integrals, which is typically intractable. In constrast, when computing its score, we obtain $\nabla_\mathbf{x} \log p_\theta(\mathbf{x}) = -\nabla_\mathbf{x} E_\theta(\mathbf{x})$ which does not require computing the normalizing constant $Z_\theta$.
#
# In fact, any neural network that maps an input vector $\mathbf{x} \in \mathbb{R}^d$ to an output vector $\mathbf{y} \in \mathbb{R}^d$ can be used as a score-based model, as long as the output and input have the same dimensionality. This yields huge flexibility in choosing model architectures.
#
# ### Perturbing Data with a Diffusion Process
#
# In order to generate samples with score-based models, we need to consider a [diffusion process](https://en.wikipedia.org/wiki/Diffusion_process) that corrupts data slowly into random noise. Scores will arise when we reverse this diffusion process for sample generation. You will see this later in the notebook.
#
# A diffusion process is a [stochastic process](https://en.wikipedia.org/wiki/Stochastic_process#:~:text=A%20stochastic%20or%20random%20process%20can%20be%20defined%20as%20a,an%20element%20in%20the%20set.) similar to [Brownian motion](https://en.wikipedia.org/wiki/Brownian_motion). Their paths are like the trajectory of a particle submerged in a flowing fluid, which moves randomly due to unpredictable collisions with other particles. Let $\{\mathbf{x}(t) \in \mathbb{R}^d \}_{t=0}^T$ be a diffusion process, indexed by the continuous time variable $t\in [0,T]$. A diffusion process is governed by a stochastic differential equation (SDE), in the following form
#
# \begin{align*}
# d \mathbf{x} = \mathbf{f}(\mathbf{x}, t) d t + g(t) d \mathbf{w},
# \end{align*}
#
# where $\mathbf{f}(\cdot, t): \mathbb{R}^d \to \mathbb{R}^d$ is called the *drift coefficient* of the SDE, $g(t) \in \mathbb{R}$ is called the *diffusion coefficient*, and $\mathbf{w}$ represents the standard Brownian motion. You can understand an SDE as a stochastic generalization to ordinary differential equations (ODEs). Particles moving according to an SDE not only follows the deterministic drift $\mathbf{f}(\mathbf{x}, t)$, but are also affected by the random noise coming from $g(t) d\mathbf{w}$.
#
# For score-based generative modeling, we will choose a diffusion process such that $\mathbf{x}(0) \sim p_0$, where we have a dataset of i.i.d. samples, and $\mathbf{x}(T) \sim p_T$, for which we have a tractable form to sample from.
#
# ### Reversing the Diffusion Process Yields Score-Based Generative Models
# By starting from a sample from $p_T$ and reversing the diffusion process, we will be able to obtain a sample from $p_\text{data}$. Crucially, the reverse process is a diffusion process running backwards in time. It is given by the following reverse-time SDE
#
# \begin{align}
#   d\mathbf{x} = [\mathbf{f}(\mathbf{x}, t) - g^2(t)\nabla_{\mathbf{x}}\log p_t(\mathbf{x})] dt + g(t) d\bar{\mathbf{w}},
# \end{align}
#
# where $\bar{\mathbf{w}}$ is a Brownian motion in the reverse time direction, and $dt$ here represents an infinitesimal negative time step. Here $p_t(\mathbf{x})$ represents the distribution of $\mathbf{x}(t)$. This reverse SDE can be computed once we know the drift and diffusion coefficients of the forward SDE, as well as the score of $p_t(\mathbf{x})$ for each $t\in[0, T]$.
#
# The overall intuition of score-based generative modeling with SDEs can be summarized in the illustration below
# ![sde schematic](https://github.com/https-deeplearning-ai/GANs-Public/blob/master/diffusion_schematic.jpg?raw=true)
#
# ### Score Estimation
#
# Based on the above intuition, we can use the time-dependent score function $\nabla_\mathbf{x} \log p_t(\mathbf{x})$ to construct the reverse-time SDE, and then solve it numerically to obtain samples from $p_0$ using samples from a prior distribution $p_T$. We can train a time-dependent score-based model $s_\theta(\mathbf{x}, t)$ to approximate $\nabla_\mathbf{x} \log p_t(\mathbf{x})$, using the following weighted sum of [denoising score matching](http://www.iro.umontreal.ca/~vincentp/Publications/smdae_techreport.pdf) objectives.
#
# \begin{align}
# \min_\theta \mathbb{E}_{t\sim \mathcal{U}(0, T)} [\lambda(t) \mathbb{E}_{\mathbf{x}(0) \sim p_0(\mathbf{x})}\mathbf{E}_{\mathbf{x}(t) \sim p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))}[ \|s_\theta(\mathbf{x}(t), t) - \nabla_{\mathbf{x}(t)}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))\|_2^2]],
# \end{align}
# where $\mathcal{U}(0,T)$ is a uniform distribution over $[0, T]$, $p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))$ denotes the transition probability from $\mathbf{x}(0)$ to $\mathbf{x}(t)$, and $\lambda(t) \in \mathbb{R}^+$ denotes a continuous weighting function.
#
# In the objective, the expectation over $\mathbf{x}(0)$ can be estimated with empirical means over data samples from $p_0$. The expectation over $\mathbf{x}(t)$ can be estimated by sampling from $p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))$, which is efficient when the drift coefficient $\mathbf{f}(\mathbf{x}, t)$ is affine. The weight function $\lambda(t)$ is typically chosen to be inverse proportional to $\mathbb{E}[\|\nabla_{\mathbf{x}}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0)) \|_2^2]$.

# %% [markdown]
# ### Time-Dependent Score-Based Model
#
# There are no restrictions on the network architecture of time-dependent score-based models, except that their output should have the same dimensionality as the input, and they should be conditioned on time.
#
# Several useful tips on architecture choice:
# * It usually performs well to use the [U-net](https://arxiv.org/abs/1505.04597) architecture as the backbone of the score network $s_\theta(\mathbf{x}, t)$,
#
# * We can incorporate the time information via [Gaussian random features](https://arxiv.org/abs/2006.10739). Specifically, we first sample $\omega \sim \mathcal{N}(\mathbf{0}, s^2\mathbf{I})$ which is subsequently fixed for the model (i.e., not learnable). For a time step $t$, the corresponding Gaussian random feature is defined as
# \begin{align}
#   [\sin(2\pi \omega t) ; \cos(2\pi \omega t)],
# \end{align}
# where $[\vec{a} ; \vec{b}]$ denotes the concatenation of vector $\vec{a}$ and $\vec{b}$. This Gaussian random feature can be used as an encoding for time step $t$ so that the score network can condition on $t$ by incorporating this encoding. We will see this further in the code.
#
# * We can rescale the output of the U-net by $1/\sqrt{\mathbb{E}[\|\nabla_{\mathbf{x}}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0)) \|_2^2]}$. This is because the optimal $s_\theta(\mathbf{x}(t), t)$ has an $\ell_2$-norm close to $\mathbb{E}[\|\nabla_{\mathbf{x}}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))]\|_2$, and the rescaling helps capture the norm of the true score. Recall that the training objective contains sums of the form
# \begin{align*}
# \mathbf{E}_{\mathbf{x}(t) \sim p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))}[ \|s_\theta(\mathbf{x}(t), t) - \nabla_{\mathbf{x}(t)}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))\|_2^2]].
# \end{align*}
# Therefore, it is natural to expect that the optimal score model $s_\theta(\mathbf{x}, t) \approx \nabla_{\mathbf{x}(t)} \log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))$.
#
# * Use [exponential moving average](https://discuss.pytorch.org/t/how-to-apply-exponential-moving-average-decay-for-variables/10856/3) (EMA) of weights when sampling. This can greatly improve sample quality, but requires slightly longer training time, and requires more work in implementation. We do not include this in this tutorial, but highly recommend it when you employ score-based generative modeling to tackle more challenging real problems.

# %%
#@title Defining a time-dependent score-based model (double click to expand or collapse)

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class GaussianFourierProjection(nn.Module):
  """Gaussian random features for encoding time steps."""  
  def __init__(self, embed_dim, scale=8.):
    super().__init__()
    # Randomly sample weights during initialization. These weights are fixed 
    # during optimization and are not trainable.
    self.W = nn.Parameter(torch.randn(embed_dim // 2) * scale, requires_grad=False)
  def forward(self, x):
    x_proj = x[:, None] * self.W[None, :] * 2 * np.pi
    return torch.cat([torch.sin(x_proj), torch.cos(x_proj)], dim=-1)


class Dense(nn.Module):
  """A fully connected layer that reshapes outputs to feature maps."""
  def __init__(self, input_dim, output_dim):
    super().__init__()
    self.dense = nn.Linear(input_dim, output_dim)
  def forward(self, x):
    return self.dense(x)[..., None, None]


class ScoreNet(nn.Module):
  """A time-dependent score-based model built upon U-Net architecture."""

  def __init__(self, noise_scale, channels=[32, 64, 128, 256], embed_dim=256):
    """
      Initialize a time-dependent score-based network.

      noise_scale: 
        a function that takes time t and gives the variance of 
        the perturbation kernel p_{0t}(x(t) | x(0)).
      channels: 
        the number of channels for feature maps of each resolution.
      embed_dim:
        the dimensionality of Gaussian random feature embeddings.
    """
    super().__init__()
    # Gaussian random feature embedding layer for time
    self.embed = GaussianFourierProjection(embed_dim=embed_dim)    
    # Encoding layers where the resolution decreases
    self.conv1 = nn.Conv2d(1, channels[0], 3, stride=1, bias=False)
    self.dense1 = Dense(embed_dim, channels[0])
    self.gnorm1 = nn.GroupNorm(4, num_channels=channels[0])
    self.conv2 = nn.Conv2d(channels[0], channels[1], 3, stride=2, bias=False)
    self.dense2 = Dense(embed_dim, channels[1])
    self.gnorm2 = nn.GroupNorm(32, num_channels=channels[1])
    self.conv3 = nn.Conv2d(channels[1], channels[2], 3, stride=2, bias=False)
    self.dense3 = Dense(embed_dim, channels[2])
    self.gnorm3 = nn.GroupNorm(32, num_channels=channels[2])
    self.conv4 = nn.Conv2d(channels[2], channels[3], 3, stride=2, bias=False)
    self.dense4 = Dense(embed_dim, channels[3])
    self.gnorm4 = nn.GroupNorm(32, num_channels=channels[3])    

    # Decoding layers where the resolution increases
    self.tconv4 = nn.ConvTranspose2d(channels[3], channels[2], 3, stride=2, bias=False)
    self.dense5 = Dense(embed_dim, channels[2])
    self.tgnorm4 = nn.GroupNorm(32, num_channels=channels[2])
    self.tconv3 = nn.ConvTranspose2d(channels[2] + channels[2], channels[1], 3, stride=2, bias=False, output_padding=1)    
    self.dense6 = Dense(embed_dim, channels[1])
    self.tgnorm3 = nn.GroupNorm(32, num_channels=channels[1])
    self.tconv2 = nn.ConvTranspose2d(channels[1] + channels[1], channels[0], 3, stride=2, bias=False, output_padding=1)    
    self.dense7 = Dense(embed_dim, channels[0])
    self.tgnorm2 = nn.GroupNorm(32, num_channels=channels[0])
    self.tconv1 = nn.ConvTranspose2d(channels[0] + channels[0], 1, 3, stride=1)
    
    # The swish activation function
    self.act = lambda x: x * torch.sigmoid(x)
    self.noise_scale = noise_scale
  
  def forward(self, x, t): 
    # Obtain the Gaussian random feature embedding for t   
    embed = self.act(self.embed(t))    
    # Encoding path
    h1 = self.conv1(x)    
    ## Incorporate information from t
    h1 += self.dense1(embed)
    ## Group normalization
    h1 = self.gnorm1(h1)
    h1 = self.act(h1)
    h2 = self.conv2(h1)
    h2 += self.dense2(embed)
    h2 = self.gnorm2(h2)
    h2 = self.act(h2)
    h3 = self.conv3(h2)
    h3 += self.dense3(embed)
    h3 = self.gnorm3(h3)
    h3 = self.act(h3)
    h4 = self.conv4(h3)
    h4 += self.dense4(embed)
    h4 = self.gnorm4(h4)
    h4 = self.act(h4)

    # Decoding path
    h = self.tconv4(h4)
    ## Skip connection from the encoding path
    h += self.dense5(embed)
    h = self.tgnorm4(h)
    h = self.act(h)
    h = self.tconv3(torch.cat([h, h3], dim=1))
    h += self.dense6(embed)
    h = self.tgnorm3(h)
    h = self.act(h)
    h = self.tconv2(torch.cat([h, h2], dim=1))
    h += self.dense7(embed)
    h = self.tgnorm2(h)
    h = self.act(h)
    h = self.tconv1(torch.cat([h, h1], dim=1))

    # Normalize output based on the norm of perturbation kernels.
    h = h / self.noise_scale(t)[:, None, None, None]
    return h

# %% [markdown]
# ## Training with Weighted Sum of Denoising Score Matching Objectives
#
# Now let's get our hands dirty on training. First of all, we need to specify an SDE that perturbs the data distribution $p_0$ to a prior distribution $p_T$. We choose the following SDE
# \begin{align*}
# d \mathbf{x} = \sqrt{\frac{d [\sigma^2(t)]}{dt}} d\mathbf{w},
# \end{align*}
# where $\sigma(t) = \sigma_{\text{min}}(\frac{\sigma_{\text{max}}}{\sigma_{\text{min}}})^t$, $t\in[0,1]$. In this case,
# \begin{align*}
# p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0)) = \mathcal{N}(\mathbf{x}(t); \mathbf{x}(0), [\sigma^2(t) - \sigma^2(0)]\mathbf{I})
# \end{align*}
# and $\lambda(t) \propto \sigma^2(t) - \sigma^2(0)$.
#
# When $\sigma_{\text{max}}$ is large enough, the distribution of $p_1$ is
# \begin{align*}
# \int p_0(\mathbf{y})\mathcal{N}(\mathbf{x}; \mathbf{y}, [\sigma_{\text{max}}^2 - \sigma_{\text{min}}^2]\mathbf{I}) d \mathbf{y} \approx \mathbf{N}(\mathbf{x}; \mathbf{0}, [\sigma_{\text{max}}^2 - \sigma_{\text{min}}^2]\mathbf{I}),
# \end{align*}
# which is easy to sample from.
#
# Intuitively, this SDE captures a continuum of Gaussian perturbations with variance function $\sigma(t)^2 - \sigma^2(0)$, where $\sigma(t)$ is a strictly increasing function that grows exponentially fast. This continuum of perturbations allows us to gradually transfer samples from a data distribution $p_0$ to a simple Gaussian distribution $p_1$.

# %%
#@title Loss function (double click to expand or collapse)
def noise_scale(t, sigma_min=0.01, sigma_max=10, grad=False):
  """
  Compute quantities related to the perturbation kernel p_{0t}(x(t) | x(0)).

  t: a vector of time steps.
  sigma_min: the minimum value of the sigma function.
  sigma_max: the maximum value of the sigma function.
  grad: if False, only return the variance of p_{0t}(x(t) | x(0)). 
    Otherwise return both the variance and the gradient of sigma^2(t).
    This gradient will be useful for sample generation.
  """
  noise = sigma_min * (sigma_max / sigma_min)**t
  if not grad:
    return torch.sqrt(noise**2 - sigma_min**2)
  else:
    dnoise_dt = sigma_min * (sigma_max / sigma_min)**t * np.log(sigma_max/sigma_min)
    dnoise2_dt = 2 * noise * dnoise_dt
    return torch.sqrt(noise**2 - sigma_min**2), dnoise2_dt

def loss_func(model, x, noise_scale, eps=1e-3):
  """
  The loss function for training score-based generative models.

  model: a PyTorch model instance that represents a time-dependent score-based model.
  x: a mini-batch of input images.
  noise_scale: a function that computes the variance of perturbation kernels.
  eps: a tolerance value for numerical stability.
  """
  random_t = torch.rand(x.shape[0], device=x.device) * (1. - eps) + eps
  noise_scales = noise_scale(random_t)
  z = torch.randn_like(x)
  perturbed_x = x + z * noise_scales[:, None, None, None]
  score = model(perturbed_x, random_t)
  loss = torch.sum((score * noise_scales[:, None, None, None] + z).reshape(x.shape[0], -1)**2, dim=-1).mean()
  return loss

# %%
#@title Training (double click to expand or collapse)

import torch
import functools
from torch.optim import Adam
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torchvision.datasets import MNIST
import tqdm

device = 'cuda' #@param ['cuda', 'cpu'] {'type':'string'}

sigma_min = 0.01 #@param {'type':'number'}
sigma_max = 22 #@param {'type':'number'}
noise_scale_func = functools.partial(noise_scale, sigma_min=sigma_min, sigma_max=sigma_max, grad=False)
score_model = torch.nn.DataParallel(ScoreNet(noise_scale=noise_scale_func))
score_model = score_model.to(device)

n_epochs =  50 #@param {'type':'integer'}
## size of a mini-batch
batch_size =  32 #@param {'type':'integer'}
## learning rate
lr=1e-4 #@param {'type':'number'}

dataset = MNIST('.', train=True, transform=transforms.ToTensor(), download=True)
data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4)

optimizer = Adam(score_model.parameters(), lr=lr)
for epoch in range(n_epochs):
  avg_loss = 0.
  num_items = 0
  for x, y in tqdm.notebook.tqdm(data_loader):
    optimizer.zero_grad()
    x = x.to(device)    
    loss = loss_func(score_model, x, noise_scale_func)
    loss.backward()
    optimizer.step()
    avg_loss += loss.item() * x.shape[0]
    num_items += x.shape[0]
  # Print the averaged training loss so far.
  print(f'epoch: {epoch}, average loss: {avg_loss / num_items}')
  # Save one checkpoint after each epoch of training.
  torch.save(score_model.state_dict(), f'ckpt.pth')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw
# Processing...
# Done!
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 0, average loss: 461.0495142903646
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 1, average loss: 188.98289863688152
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 2, average loss: 142.40901701253256
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 3, average loss: 123.45852112223308
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 4, average loss: 112.21409476114908
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 5, average loss: 105.51488899332682
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 6, average loss: 101.0819811319987
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 7, average loss: 95.38199491780598
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 8, average loss: 92.46577931315105
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 9, average loss: 90.24367910766601
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 10, average loss: 87.44425549926758
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 11, average loss: 86.04429627685546
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 12, average loss: 83.77249763590495
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 13, average loss: 82.03748968302409
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 14, average loss: 80.7232715209961
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 15, average loss: 78.71808280741374
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 16, average loss: 77.60795349324545
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 17, average loss: 76.48010199584961
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 18, average loss: 75.36023204752604
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 19, average loss: 74.44798456827799
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 20, average loss: 74.09960429280599
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 21, average loss: 73.657296677653
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 22, average loss: 72.29290933532715
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 23, average loss: 72.02083998413086
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 24, average loss: 71.45039631652833
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 25, average loss: 70.92047438354493
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 26, average loss: 69.50142676595053
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 27, average loss: 68.74914218037924
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 28, average loss: 68.22032446085612
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 29, average loss: 67.57813993530273
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 30, average loss: 67.13620872294108
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 31, average loss: 67.18488820902506
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 32, average loss: 66.59399514973958
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 33, average loss: 65.86248985900879
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 34, average loss: 65.77004878540039
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 35, average loss: 64.89736489359538
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 36, average loss: 64.82477123718262
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 37, average loss: 63.7788689453125
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 38, average loss: 63.52531878356933
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 39, average loss: 63.61133885599772
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 40, average loss: 62.928574635823566
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 41, average loss: 62.35363714090983
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 42, average loss: 61.801228931681315
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 43, average loss: 61.96817426147461
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 44, average loss: 61.2532484395345
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 45, average loss: 60.642808739217124
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 46, average loss: 61.21659654744466
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 47, average loss: 60.44800771891276
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 48, average loss: 59.69015892232259
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# epoch: 49, average loss: 59.99877931925456

# %% [markdown]
# ## Sampling with Numerical SDE Solvers
# Recall that for any SDE of the form
# \begin{align*}
# d \mathbf{x} = \mathbf{f}(\mathbf{x}, t) dt + g(t) d\mathbf{w},
# \end{align*}
# the reverse-time SDE is given by
# \begin{align*}
# d \mathbf{x} = [\mathbf{f}(\mathbf{x}, t) + g(t)^2 \nabla_\mathbf{x} \log p_t(\mathbf{x})] dt + g(t) d \bar{\mathbf{w}}.
# \end{align*}
# Since we have chosen the forward SDE to be
# \begin{align*}
# d \mathbf{x} = \sqrt{\frac{d [\sigma^2(t)]}{dt}} d\mathbf{w},
# \end{align*}
# where $\sigma(t) = \sigma_{\text{min}}(\frac{\sigma_{\text{max}}}{\sigma_{\text{min}}})^t$, $t\in[0,1]$. The reverse-time SDE is given by
# \begin{align*}
# d\mathbf{x} = -\frac{d[\sigma^2(t)]}{dt} \nabla_\mathbf{x} \log p_t(\mathbf{x}) dt + \sqrt{\frac{d[\sigma^2(t)]}{d t}} d \bar{\mathbf{w}}.
# \end{align*}
# To sample from our time-dependent score-based model $s_\theta(\mathbf{x}, t)$, we can first draw a sample from $p_1 \approx \mathbf{N}(\mathbf{x}; \mathbf{0}, [\sigma_{\text{max}}^2 - \sigma_{\text{min}}^2]\mathbf{I})$, and then solve the reverse-time SDE with numerical methods.
#
# Specifically, using our time-dependent score-based model, the reverse-time SDE can be approximated by
# \begin{align*}
# d\mathbf{x} = -\frac{d[\sigma^2(t)]}{dt} s_\theta(\mathbf{x}, t) dt + \sqrt{\frac{d[\sigma^2(t)]}{d t}} d \bar{\mathbf{w}}
# \end{align*}
#
# Next, one can use numerical methods to solve for the reverse-time SDE, such as the [Euler-Maruyama](https://en.wikipedia.org/wiki/Euler%E2%80%93Maruyama_method) approach. It is based on a simple discretization to the SDE, replacing $dt$ with $\Delta t$ and $d \mathbf{w}$ with $\mathbf{z} \sim \mathcal{N}(\mathbf{0}, g^2(t) \Delta t \mathbf{I})$. When applied to our reverse-time SDE, we can obtain the following iteration rule
# \begin{align}
# \mathbf{x}_{t-\Delta t} = \mathbf{x}_t + \frac{d[\sigma^2(t)]}{dt}s_\theta(\mathbf{x}_t, t)\Delta t + \sqrt{\frac{d[\sigma^2(t)]}{dt}\Delta t} \mathbf{z}_t,
# \end{align}
# where $\mathbf{z}_t \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$.

# %% [markdown]
# ## Sampling with Predictor-Corrector Methods
#
# Aside from generic numerical SDE solvers, we can leverage special properties of our reverse-time SDE for better solutions. Since we have an estimate of the score of $p_t(\mathbf{x}(t))$ via the score-based model, i.e., $s_\theta(\mathbf{x}, t) \approx \nabla_{\mathbf{x}(t)} \log p_t(\mathbf{x}(t))$, we can leverage score-based MCMC approaches, such as Langevin MCMC, to correct the solution obtained by numerical SDE solvers.
#
# Score-based MCMC approaches can produce samples from a distribution $p(\mathbf{x})$ once its score $\nabla_\mathbf{x} \log p(\mathbf{x})$ is known. For example, Langevin MCMC operates by running the following iteration rule for $i=1,2,\cdots, N$:
# \begin{align*}
# \mathbf{x}_{i+1} = \mathbf{x}_{i} + \epsilon \nabla_\mathbf{x} \log p(\mathbf{x}_i) + \sqrt{2\epsilon} \mathbf{z}_i,
# \end{align*}
# where $\mathbf{z}_i \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$, $\epsilon > 0$ is the step size, and $\mathbf{x}_1$ is initialized from any prior distribution $\pi(\mathbf{x}_1)$. When $N\to\infty$ and $\epsilon \to 0$, the final value $\mathbf{x}_{N+1}$ becomes a sample from $p(\mathbf{x})$ under some regularity conditions. Therefore, given $s_\theta(\mathbf{x}, t) \approx \nabla_\mathbf{x} \log p_t(\mathbf{x})$, we can get an approximate sample from $p_t(\mathbf{x})$ by running several steps of Langevin MCMC, replacing $\nabla_\mathbf{x} \log p_t(\mathbf{x})$ with $s_\theta(\mathbf{x}, t)$ in the iteration rule.
#
# Predictor-Corrector samplers combine both numerical solvers for the reverse-time SDE and the Langevin MCMC approach. In particular, we first apply one step of numerical SDE solver to obtain $\mathbf{x}_{t-\Delta t}$ from $\mathbf{x}_t$, which is called the "predictor" step. Next, we apply several steps of Langevin MCMC to refine $\mathbf{x}_t$, such that $\mathbf{x}_t$ becomes a more accurate sample from $p_{t-\Delta t}(\mathbf{x})$. This is the "corrector" step as the MCMC helps reduce the error of the numerical SDE solver.

# %% [markdown]
# ## Sampling with Numerical ODE Solvers
#
# For any SDE of the form
# \begin{align*}
# d \mathbf{x} = \mathbf{f}(\mathbf{x}, t) d t + g(t) d \mathbf{w},
# \end{align*}
# there exists an associated ordinary differential equation (ODE)
# \begin{align*}
# d \mathbf{x} = \bigg[\mathbf{f}(\mathbf{x}, t) - \frac{1}{2}g(t)^2 \nabla_\mathbf{x} \log p_t(\mathbf{x})\bigg] dt,
# \end{align*}
# such that their trajectories have the same mariginal probability density $p_t(\mathbf{x})$. We call this ODE the *probability flow ODE*.
#
# Therefore, we can start from a sample from $p_T$, integrate the ODE in the reverse time direction, and then get a sample from $p_0 = p_\text{data}$. In particular, for our chosen forward SDE, we can integrate the following SDE from $t=T$ to $0$ for sample generation
# \begin{align*}
# d\mathbf{x} =  -\frac{1}{2}\frac{d[\sigma^2(t)]}{d t} s_\theta(\mathbf{x}, t) dt.
# \end{align*}
# This can be done using many heavily-optimized black-box ODE solvers provided by packages such as `scipy`.

# %%
#@title SDE sampling (double click to expand or collapse)

## The number of sampling steps.
num_steps = 500 #@param {'type':'integer'}
def sde_sampler(score_model, noise_scale, batch_size=64, num_steps=num_steps, device='cuda'):
  """
  Generate samples from score-based models with numerical SDE solvers.

  score_model: a PyTorch model that represents the time-dependent score-based model.
  noise_scale: a function that gives a tuple: (the variance of p_{0t}(x(t) | x(0)) and
    , the gradient of sigma^2(t) ).
  batch_size: the number of samplers to generate by calling this function once.
  num_steps: the number of sampling steps. Also equivalent to the number of discretized time steps.
  device: 'cuda' for running on GPUs, and 'cpu' for running on CPUs.
  """
  t = torch.ones(batch_size, device=device)
  init_x = torch.randn(batch_size, 1, 28, 28, device=device) * noise_scale(t)[0][:, None, None, None]
  time_steps = np.linspace(1., 1e-3, num_steps)
  step_size = time_steps[0] - time_steps[1]
  x = init_x
  with torch.no_grad():
    for time_step in tqdm.notebook.tqdm(time_steps):      
      batch_time_step = torch.ones(batch_size, device=device) * time_step
      next_x = x + noise_scale(batch_time_step)[1][:, None, None, None] * score_model(x, batch_time_step) * step_size
      next_x = next_x + torch.sqrt(noise_scale(batch_time_step)[1] * step_size)[:, None, None, None] * torch.randn_like(x)
      x = next_x       
    return x

# %%
#@title PC sampling (double click to expand or collapse)

signal_to_noise_ratio = 0.15 #@param {'type':'number'}

## The number of sampling steps.
num_steps = 500 #@param {'type':'integer'}
def pc_sampler(score_model, noise_scale, batch_size=64, num_steps=num_steps, snr=signal_to_noise_ratio, device='cuda'):
  """
  Generate samples from score-based models with Predictor-Corrector method.

  score_model: a PyTorch model that represents the time-dependent score-based model.
  noise_scale: a function that gives a tuple: (the variance of p_{0t}(x(t) | x(0)) and
    , the gradient of sigma^2(t) ).
  batch_size: the number of samplers to generate by calling this function once.
  num_steps: the number of sampling steps. Also equivalent to the number of discretized time steps.
  device: 'cuda' for running on GPUs, and 'cpu' for running on CPUs.
  """
  t = torch.ones(batch_size, device=device)
  init_x = torch.randn(batch_size, 1, 28, 28, device=device) * noise_scale(t)[0][:, None, None, None]
  time_steps = np.linspace(1., 1e-3, num_steps)
  step_size = time_steps[0] - time_steps[1]
  x = init_x
  with torch.no_grad():
    for time_step in tqdm.notebook.tqdm(time_steps):      
      # Corrector step
      batch_time_step = torch.ones(batch_size, device=device) * time_step
      next_x = x + noise_scale(batch_time_step)[1][:, None, None, None] * score_model(x, batch_time_step) * step_size
      next_x = next_x + torch.sqrt(noise_scale(batch_time_step)[1] * step_size)[:, None, None, None] * torch.randn_like(x)
      x = next_x 

      # Predictor step
      grad = score_model(x, batch_time_step)
      grad_norm = torch.norm(grad.reshape(grad.shape[0], -1), dim=-1).mean()
      noise_norm = np.sqrt(np.prod(x.shape[1:]))
      langevin_step_size = 2 * (snr * noise_norm / grad_norm)**2
      x = x + langevin_step_size * grad + torch.sqrt(2 * langevin_step_size) * torch.randn_like(x)      
    return x

# %%
#@title ODE sampling (double click to expand or collapse)

from scipy import integrate

## The error tolerance for the black-box ODE solver
error_tolerance = 1e-5 #@param {'type': 'number'}
def ode_sampler(score_model, noise_scale, batch_size=64, atol=error_tolerance, rtol=error_tolerance, device='cuda', z=None):
  """
  Generate samples from score-based models with black-box ODE solvers.

  score_model: a PyTorch model that represents the time-dependent score-based model.
  noise_scale: a function that gives a tuple: (the variance of p_{0t}(x(t) | x(0)) and
    , the gradient of sigma^2(t) ).
  batch_size: the number of samplers to generate by calling this function once.
  atol: tolerance of absolute errors.
  rtol: tolerance of relative errors.
  device: 'cuda' for running on GPUs, and 'cpu' for running on CPUs.
  z: the latent code that governs the final sample. If None, we start from p_1;
    otherwise, we start from the given z.
  """
  t = torch.ones(batch_size, device=device)
  # Create the latent code
  if z is None:
    init_x = torch.randn(batch_size, 1, 28, 28, device=device) * noise_scale(t)[0][:, None, None, None]
  else:
    init_x = z
    
  shape = init_x.shape

  def score_eval_wrapper(sample, time_steps):
    """A wrapper of the score-based model for use by the ODE solver."""
    sample = torch.tensor(sample, device=device, dtype=torch.float32).reshape(shape)
    time_steps = torch.tensor(time_steps, device=device, dtype=torch.float32).reshape((sample.shape[0], ))    
    with torch.no_grad():    
      score = score_model(sample, time_steps)
    return score.cpu().numpy().reshape((-1,)).astype(np.float64)
  
  def ode_func(t, x):        
    """The ODE function for use by the ODE solver."""
    time_steps = np.ones((shape[0],)) * t
    
    return  -0.5 * noise_scale(torch.tensor(t))[1].cpu().numpy() * score_eval_wrapper(x, time_steps)    
  
  # Run the black-box ODE solver.
  res = integrate.solve_ivp(ode_func, (1., 1e-2), init_x.reshape(-1).cpu().numpy(), rtol=rtol, atol=atol, method='RK45')  
  print(f"Number of function evaluations: {res.nfev}")
  x = torch.tensor(res.y[:, -1], device=device).reshape(shape)

  return x

# %%
#@title Sampling (double click to expand or collapse)

from torchvision.utils import make_grid

## Load the pre-trained checkpoint from disk.
device = 'cuda' #@param ['cuda', 'cpu'] {'type':'string'}
ckpt = torch.load('ckpt.pth', map_location=device)
score_model.load_state_dict(ckpt)

noise_scale_func = functools.partial(noise_scale, sigma_min=sigma_min, sigma_max=sigma_max, grad=True)
sample_batch_size = 64 #@param {'type':'integer'}
sampler = pc_sampler #@param ['sde_sampler', 'pc_sampler', 'ode_sampler'] {'type': 'raw'}

## Generate samples using the specified sampler.
samples = sampler(score_model, noise_scale_func, sample_batch_size, device=device)

## Sample visualization.
samples = samples.clamp(0.0, 1.0)
import matplotlib.pyplot as plt
sample_grid = make_grid(samples, nrow=int(np.sqrt(sample_batch_size)))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=500.0), HTML(value='')))

# %% [markdown]
# ## Likelihood Computation
#
# A by-product of the probability flow ODE formulation is likelihood computation. Suppose we have a differentiable one-to-one mapping $\mathbf{h}$ that transforms a data sample $\mathbf{x} \sim p_0$ to a prior distribution $\mathbf{h}(\mathbf{x}) \sim p_1$. We can compute the likelihood of $p_0(\mathbf{x})$ via the following [change-of-variable formula](https://en.wikipedia.org/wiki/Probability_density_function#Function_of_random_variables_and_change_of_variables_in_the_probability_density_function)
# \begin{align*}
# p_0(\mathbf{x}) = p_1(\mathbf{h}(\mathbf{x})) |\operatorname{det}(J_\mathbf{h}(\mathbf{x}))|,
# \end{align*}
# where $J_\mathbf{h}(\mathbf{x})$ represents the Jacobian of the mapping $\mathbf{h}$, and we assume it is efficient to evaluate the likelihood of the prior distribution $p_1$.
#
# Similarly, an ODE is also a one-to-one mapping from $\mathbf{x}(0)$ to $\mathbf{x}(1)$. For ODEs of the form
# \begin{align*}
# d \mathbf{x} = \mathbf{f}(\mathbf{x}, t) dt,
# \end{align*}
# there exists an [instantaneous change-of-variable formula](https://arxiv.org/abs/1806.07366) that connects the probability of $p_0(\mathbf{x})$ and $p_1(\mathbf{x})$, given by
# \begin{align*}
# p_0 (\mathbf{x}(0)) = e^{\int_0^1 \operatorname{div} \mathbf{f}(\mathbf{x}(t), t) d t} p_1(\mathbf{x}(1)),
# \end{align*}
# where $\operatorname{div}$ denotes the divergence function (trace of Jacobian).
#
# In practice, this divergence function can be hard to evaluate for general vector-valued function $\mathbf{f}$, but we can use an unbiased estimator, named [Skilling-Hutchinson estimator](http://blog.shakirm.com/2015/09/machine-learning-trick-of-the-day-3-hutchinsons-trick/), to approximate the trace. Let $\boldsymbol \epsilon \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$. The Skilling-Hutchinson estimator is based on the fact that
# \begin{align*}
# \operatorname{div} \mathbf{f}(\mathbf{x}) = \mathbb{E}_{\boldsymbol\epsilon \sim \mathcal{N}(\mathbf{0}, \mathbf{I})}[\boldsymbol\epsilon^\intercal  J_\mathbf{f}(\mathbf{x}) \boldsymbol\epsilon].
# \end{align*}
# Therefore, we can simply sample a random vector $\boldsymbol \epsilon \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$, and then use $\boldsymbol \epsilon^\intercal J_\mathbf{f}(\mathbf{x}) \boldsymbol \epsilon$ to estimate the divergence of $\mathbf{f}(\mathbf{x})$. This estimator only requires computing the Jacobian-vector product $J_\mathbf{f}(\mathbf{x})\boldsymbol \epsilon$, which is typically efficient.
#
# As a result, for our probability flow ODE, we can compute the (log) data likelihood with the following
# \begin{align*}
# \log p_0(\mathbf{x}(0)) = \log p_1(\mathbf{x}(1)) -\frac{1}{2}\int_0^1 \frac{d[\sigma^2(t)]}{dt} \operatorname{div} s_\theta(\mathbf{x}(t), t) dt.
# \end{align*}
# With the Skilling-Hutchinson estimator, we can compute the divergence via
# \begin{align*}
# \operatorname{div} s_\theta(\mathbf{x}(t), t) = \mathbb{E}_{\boldsymbol\epsilon \sim \mathcal{N}(\mathbf{0}, \mathbf{I})}[\boldsymbol\epsilon^\intercal  J_{s_\theta}(\mathbf{x}(t), t) \boldsymbol\epsilon].
# \end{align*}
# Afterwards, we can compute the integral with numerical integrators. This gives us an unbiased estimate to the true data likelihood, and we can make it more and more accurate when we run it multiple times and take the average. The numerical integrator requires $\mathbf{x}(t)$ as a function of $t$, which can be obtained by solving the original probability flow ODE.

# %%
#@title Likelihood function (double click to expand or collapse)

def prior_likelihood(z, sigma):
  """The likelihood of a Gaussian distribution with mean zero and 
      standard deviation sigma."""
  shape = z.shape
  N = np.prod(shape[1:])
  return -N / 2. * torch.log(2*np.pi*sigma**2) - torch.sum(z**2, dim=(1,2,3)) / (2 * sigma**2)

def ode_likelihood(x, score_model, noise_scale, batch_size=64, device='cuda'):

  # Draw the random Gaussian sample for Skilling-Hutchinson's estimator.
  epsilon = torch.randn_like(x)
      
  def divergence_eval(sample, time_steps, epsilon):      
    """Compute the divergence of the score-based model with Skilling-Hutchinson."""
    with torch.enable_grad():
      sample.requires_grad_(True)
      score_e = torch.sum(score_model(sample, time_steps) * epsilon)
      grad_score_e = torch.autograd.grad(score_e, sample)[0]
    return torch.sum(grad_score_e * epsilon, dim=(1, 2, 3))    
  
  shape = x.shape

  def score_eval_wrapper(sample, time_steps):
    """A wrapper for evaluating the score-based model for the black-box ODE solver."""
    sample = torch.tensor(sample, device=device, dtype=torch.float32).reshape(shape)
    time_steps = torch.tensor(time_steps, device=device, dtype=torch.float32).reshape((sample.shape[0], ))    
    with torch.no_grad():    
      score = score_model(sample, time_steps)
    return score.cpu().numpy().reshape((-1,)).astype(np.float64)
  
  def divergence_eval_wrapper(sample, time_steps):
    """A wrapper for evaluating the divergence of score for the black-box ODE solver."""
    with torch.no_grad():
      # Obtain x(t) by solving the probability flow ODE.
      sample = torch.tensor(sample, device=device, dtype=torch.float32).reshape(shape)
      time_steps = torch.tensor(time_steps, device=device, dtype=torch.float32).reshape((sample.shape[0], ))    
      # Compute likelihood.
      div = divergence_eval(sample, time_steps, epsilon)
      return div.cpu().numpy().reshape((-1,)).astype(np.float64)
  
  def ode_func(t, x):
    """The ODE function for the black-box solver."""
    time_steps = np.ones((shape[0],)) * t    
    sample = x[:-shape[0]]
    logp = x[-shape[0]:]
    sample_grad = -0.5 * noise_scale(torch.tensor(t))[1].cpu().numpy() * score_eval_wrapper(sample, time_steps)
    logp_grad = -0.5 * noise_scale(torch.tensor(t))[1].cpu().numpy() * divergence_eval_wrapper(sample, time_steps)
    return np.concatenate([sample_grad, logp_grad], axis=0)

  init = np.concatenate([x.cpu().numpy().reshape((-1,)), np.zeros((shape[0],))], axis=0)
  # Black-box ODE solver
  res = integrate.solve_ivp(ode_func, (1e-3, 1.), init, rtol=1e-5, atol=1e-5, method='RK45')  
  zp = torch.tensor(res.y[:, -1], device=device)
  z = zp[:-shape[0]].reshape(shape)
  delta_logp = zp[-shape[0]:].reshape(shape[0])
  sigma_max = noise_scale(torch.ones((), device=device))[0]
  prior_logp = prior_likelihood(z, sigma_max)
  bpd = -(prior_logp + delta_logp) / np.log(2)
  N = np.prod(shape[1:])
  bpd = bpd / N + 8.
  return z, bpd

# %%
#@title Computing likelihood on the dataset (double click to expand or collapse)

device = 'cuda' #@param ['cuda', 'cpu'] {'type':'string'}

ckpt = torch.load('ckpt.pth', map_location=device)
score_model.load_state_dict(ckpt)

noise_scale_func = functools.partial(noise_scale, sigma_min=sigma_min, sigma_max=sigma_max, grad=True)

all_bpds = 0.
all_items = 0
try:
  for x, _ in tqdm.notebook.tqdm(data_loader):
    x = x.to(device)
    # uniform dequantization
    x = (x * 255. + torch.rand_like(x)) / 256.    
    _, bpd = ode_likelihood(x, score_model, noise_scale_func, x.shape[0], device=device)
    all_bpds += bpd.sum()
    all_items += bpd.shape[0]
    print(f"bpd (running average): {all_bpds / all_items}")
  print(f"bpd (full average): {all_bpds/all_items}")
except KeyboardInterrupt:
  # Remove the error message when interuptted by keyboard or GUI.
  pass
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1875.0), HTML(value='')))
# bpd (running average): 2.2137473948313415
# bpd (running average): 2.3776206424118724
# bpd (running average): 2.4583390344851894
# bpd (running average): 2.4579960892640353
# bpd (running average): 2.4931217850854974
# bpd (running average): 2.4982986453488105
# bpd (running average): 2.44038804320414
# bpd (running average): 2.4141942679920843
# bpd (running average): 2.436352742789562
# bpd (running average): 2.4426548007533975
# bpd (running average): 2.4352025616291217
# bpd (running average): 2.4027535843635923
# bpd (running average): 2.407577587848361
# bpd (running average): 2.4102228608998653
# bpd (running average): 2.4072076134429845
# bpd (running average): 2.412492261967543
# bpd (running average): 2.4180800136171894
# bpd (running average): 2.4020154737597403
# bpd (running average): 2.3940591462357026
# bpd (running average): 2.398496138206032
# bpd (running average): 2.3995714884923633
# bpd (running average): 2.3979986684886967
# bpd (running average): 2.3960003100556957
# bpd (running average): 2.3963743501787986
# bpd (running average): 2.39155801131708
# bpd (running average): 2.3864179731270454
# bpd (running average): 2.3795248203691526
# bpd (running average): 2.376794929013245
# bpd (running average): 2.3785328460737536
# bpd (running average): 2.379848307510628
# bpd (running average): 2.385557218506439
# bpd (running average): 2.3827964160018498
# bpd (running average): 2.3821626066715376
# bpd (running average): 2.3789837856580043
# bpd (running average): 2.376514187161777
# bpd (running average): 2.373492949065425
# bpd (running average): 2.3847900330624023
# bpd (running average): 2.393915098062954
# bpd (running average): 2.3876100322758407
# bpd (running average): 2.3835997099322905
# bpd (running average): 2.3855598297577263
# bpd (running average): 2.384777126243495
# bpd (running average): 2.3844571277175635
# bpd (running average): 2.386179487812704
# bpd (running average): 2.389403075878662
# bpd (running average): 2.38345687553704
# bpd (running average): 2.3881593106018095
# bpd (running average): 2.3913392134453217
# bpd (running average): 2.394054031092825
# bpd (running average): 2.3917386481066574
# bpd (running average): 2.3919475055661317
# bpd (running average): 2.396470220062348
# bpd (running average): 2.3951874283381738
# bpd (running average): 2.393013243210989
# bpd (running average): 2.393344717147043
# bpd (running average): 2.3927461235934673
# bpd (running average): 2.3944603704689325
# bpd (running average): 2.393072762291295
# bpd (running average): 2.3886621827294814
# bpd (running average): 2.3886206738956774
# bpd (running average): 2.388652709560724
# bpd (running average): 2.3888782301873275
# bpd (running average): 2.3879324947501224
# bpd (running average): 2.3837985947591545
# bpd (running average): 2.382898252809018
# bpd (running average): 2.3805814433702532
# bpd (running average): 2.379395801689852
# bpd (running average): 2.374392414939213
# bpd (running average): 2.3734418827865373
# bpd (running average): 2.375760408528469
# bpd (running average): 2.374490892251802
# bpd (running average): 2.377420916960223
# bpd (running average): 2.379956142665604
# bpd (running average): 2.3817448332393725
# bpd (running average): 2.3805538070315593
# bpd (running average): 2.3785518036850717
# bpd (running average): 2.3777343965388202
# bpd (running average): 2.379182991623661
# bpd (running average): 2.3771054681925716
# bpd (running average): 2.3785056302745993
# bpd (running average): 2.380974614243087
# bpd (running average): 2.3813753828223834
# bpd (running average): 2.3799091410055553
# bpd (running average): 2.3804621593709427
# bpd (running average): 2.3798224217269714
# bpd (running average): 2.3805011221914
# bpd (running average): 2.376954610372718
# bpd (running average): 2.3752215220022204
# bpd (running average): 2.374892598675817
# bpd (running average): 2.3775912709036637
# bpd (running average): 2.3770348144408175
# bpd (running average): 2.3754652700837595
# bpd (running average): 2.376385872347654
# bpd (running average): 2.376892259793702
# bpd (running average): 2.3760905733706945
# bpd (running average): 2.3782894768368967
# bpd (running average): 2.3742742066166747
# bpd (running average): 2.375160880252158
# bpd (running average): 2.3766150817075835
# bpd (running average): 2.3771375345433037
# bpd (running average): 2.3763623101572486
# bpd (running average): 2.3751285187675633
# bpd (running average): 2.373708781427244
# bpd (running average): 2.371729085565013
# bpd (running average): 2.3716376194521813
# bpd (running average): 2.370792252422375
# bpd (running average): 2.3711113520302383
# bpd (running average): 2.368310786040796
# bpd (running average): 2.369549498709907
# bpd (running average): 2.3681374317114825
# bpd (running average): 2.3696348562904714
# bpd (running average): 2.371971552913513
# bpd (running average): 2.3720015681136126
# bpd (running average): 2.3710933243775236
# bpd (running average): 2.372648418420112
# bpd (running average): 2.3726022942775464
# bpd (running average): 2.371341981707507
# bpd (running average): 2.373873855037604
# bpd (running average): 2.374253756990351
# bpd (running average): 2.3735056224792617
# bpd (running average): 2.374433971911021
# bpd (running average): 2.3736271493191694
# bpd (running average): 2.373566706801407
# bpd (running average): 2.3734253387429356
# bpd (running average): 2.372543480110614
# bpd (running average): 2.3717347926423065
# bpd (running average): 2.3703799044001013
# bpd (running average): 2.371769810924088
# bpd (running average): 2.3730375225041724
# bpd (running average): 2.373290405395383
# bpd (running average): 2.37263493314161
# bpd (running average): 2.3728601251893497
# bpd (running average): 2.375005521574724
# bpd (running average): 2.374679321019388
# bpd (running average): 2.3765696108211674
# bpd (running average): 2.3772016743974027
# bpd (running average): 2.3759483745497576
# bpd (running average): 2.376929335711388
# bpd (running average): 2.378703531028118
# bpd (running average): 2.3771648515624126
# bpd (running average): 2.3784560403721917
# bpd (running average): 2.3776808313015256
# bpd (running average): 2.3771942493210436
# bpd (running average): 2.3780354150776337
# bpd (running average): 2.3784174840895687
# bpd (running average): 2.379040923483441
# bpd (running average): 2.3778664576544193
# bpd (running average): 2.3793905667240094
# bpd (running average): 2.378760256934083
# bpd (running average): 2.3789007047390887
# bpd (running average): 2.3786063243631803
# bpd (running average): 2.379422899777736
# bpd (running average): 2.3799777917540954
# bpd (running average): 2.3793869878202702
# bpd (running average): 2.380085369524339
# bpd (running average): 2.379588333704569
# bpd (running average): 2.3793932237498137
# bpd (running average): 2.3795019808425883
# bpd (running average): 2.379715372450547
# bpd (running average): 2.379084531240528
# bpd (running average): 2.379509898620426
# bpd (running average): 2.379432191865303
# bpd (running average): 2.3782571967773873
# bpd (running average): 2.3763538577311767
# bpd (running average): 2.375689531226165
# bpd (running average): 2.3755459395141334
# bpd (running average): 2.3750875848930497
# bpd (running average): 2.3749080253453534
# bpd (running average): 2.374751766365248
# bpd (running average): 2.3759670507454578
# bpd (running average): 2.375620003179165
# bpd (running average): 2.37540190615602
# bpd (running average): 2.3734501227121987
# bpd (running average): 2.372814470859026
# bpd (running average): 2.3739276522754302
# bpd (running average): 2.372640898696104
# bpd (running average): 2.37288793423505
# bpd (running average): 2.371173208099505
# bpd (running average): 2.3711305499043442
# bpd (running average): 2.371666646778596
# bpd (running average): 2.3699016474977244
# bpd (running average): 2.369930994625108
# bpd (running average): 2.369616280167761
# bpd (running average): 2.369002408012621
# bpd (running average): 2.3686633640634036
# bpd (running average): 2.3680172248621405
# bpd (running average): 2.36789474500053
# bpd (running average): 2.367894637451343
# bpd (running average): 2.3674835146705266
# bpd (running average): 2.366940269106759
# bpd (running average): 2.368144372648617
# bpd (running average): 2.3667500962825487
# bpd (running average): 2.3673964228188837
# bpd (running average): 2.3669520610476846
# bpd (running average): 2.366961859455213
# bpd (running average): 2.367630675283772
# bpd (running average): 2.3676294508184395
# bpd (running average): 2.367655670720484
# bpd (running average): 2.368111079696621
# bpd (running average): 2.367649419242641
# bpd (running average): 2.3679906965290427
# bpd (running average): 2.3674623187147215
# bpd (running average): 2.3663709067403516
# bpd (running average): 2.3669252629933015
# bpd (running average): 2.3668273308806302
# bpd (running average): 2.3653763295532166
# bpd (running average): 2.365338608120805
# bpd (running average): 2.366039069219109
# bpd (running average): 2.3664923385999206
# bpd (running average): 2.366230151449692
# bpd (running average): 2.3655265647632677
# bpd (running average): 2.3659254239638803
# bpd (running average): 2.3648630823381493
# bpd (running average): 2.365421030891874
# bpd (running average): 2.3659385305866536
# bpd (running average): 2.366032732779664
# bpd (running average): 2.366886961857037
# bpd (running average): 2.36739767709605
# bpd (running average): 2.3680160101434726
# bpd (running average): 2.3675592412461777
# bpd (running average): 2.368582268513161
# bpd (running average): 2.3688705826024727
# bpd (running average): 2.369216070889923
# bpd (running average): 2.370457048678611
# bpd (running average): 2.3711619540341093
# bpd (running average): 2.371196920924084
# bpd (running average): 2.3719985621546305
# bpd (running average): 2.3718556001875766
# bpd (running average): 2.372209023099641
# bpd (running average): 2.37193745010774
# bpd (running average): 2.372443885065251
# bpd (running average): 2.3719911407389316
# bpd (running average): 2.3728721900654284
# bpd (running average): 2.372747202501045
# bpd (running average): 2.3729808085708988
# bpd (running average): 2.3724555904328195
# bpd (running average): 2.372086733171074
# bpd (running average): 2.372332017781029
# bpd (running average): 2.3714810352940274
# bpd (running average): 2.3717090740808997
# bpd (running average): 2.371972695287465
# bpd (running average): 2.37259985988061
# bpd (running average): 2.372411034106524
# bpd (running average): 2.3720413389455195
# bpd (running average): 2.371769623330836
# bpd (running average): 2.3721661131837934
# bpd (running average): 2.372135729147639
# bpd (running average): 2.3712444343360564
# bpd (running average): 2.371816579136759
# bpd (running average): 2.372485361596421
# bpd (running average): 2.372568980359058
# bpd (running average): 2.372849873137721
# bpd (running average): 2.373126965947916
# bpd (running average): 2.3719168053428947
# bpd (running average): 2.372180106163269
# bpd (running average): 2.3715305021406916
# bpd (running average): 2.371399992911196
# bpd (running average): 2.3710351204471736
# bpd (running average): 2.3718328041948995
# bpd (running average): 2.371920412121379
# bpd (running average): 2.372666476400914
# bpd (running average): 2.373187443563916
# bpd (running average): 2.3737005762454797
# bpd (running average): 2.3730492470108264
# bpd (running average): 2.3721733024836085
# bpd (running average): 2.3722420062343397
# bpd (running average): 2.3721629063575183
# bpd (running average): 2.3722031862800153
# bpd (running average): 2.37256336449788
# bpd (running average): 2.3722864262044925
# bpd (running average): 2.3730911146017095
# bpd (running average): 2.373132977355687
# bpd (running average): 2.3728053715866686
# bpd (running average): 2.372626423877245
# bpd (running average): 2.373022425454937
# bpd (running average): 2.3725040564243134
# bpd (running average): 2.372463164743372
# bpd (running average): 2.372639793882739
# bpd (running average): 2.3731085285333378
# bpd (running average): 2.3727170649712175
# bpd (running average): 2.371619913724994
# bpd (running average): 2.3717113648146326
# bpd (running average): 2.3713721389550697
# bpd (running average): 2.371835426526756
# bpd (running average): 2.3724854803337165
# bpd (running average): 2.371946882975517
# bpd (running average): 2.371516773379343
# bpd (running average): 2.371187931930201
# bpd (running average): 2.3714866536056176
# bpd (running average): 2.3711619072530854
# bpd (running average): 2.3710073211034377
# bpd (running average): 2.3711269451100914
# bpd (running average): 2.370888545751231
# bpd (running average): 2.3712939191719573
# bpd (running average): 2.371272543576511
# bpd (running average): 2.3719764719804806
# bpd (running average): 2.3716509665142724
# bpd (running average): 2.371820116138693
# bpd (running average): 2.3722048311211594
# bpd (running average): 2.3720375044501143
# bpd (running average): 2.372147073352556
# bpd (running average): 2.3712726803972837
# bpd (running average): 2.3708219708017904
# bpd (running average): 2.370175520182656
# bpd (running average): 2.3704453176976985
# bpd (running average): 2.369436856097795
# bpd (running average): 2.3685122886503667
# bpd (running average): 2.367384572120014
# bpd (running average): 2.3677488932902397
# bpd (running average): 2.3677851058887898
# bpd (running average): 2.367692534145059
# bpd (running average): 2.3675107744906034
# bpd (running average): 2.367959779274817
# bpd (running average): 2.3678205642596963
# bpd (running average): 2.3680489350314637
# bpd (running average): 2.3682671316079
# bpd (running average): 2.36801960826676
# bpd (running average): 2.3677470227689312
# bpd (running average): 2.3670329302447644
# bpd (running average): 2.367000242002386
# bpd (running average): 2.367602013964657
# bpd (running average): 2.367241889707868
# bpd (running average): 2.367484480819788
# bpd (running average): 2.367413214311609
# bpd (running average): 2.3676146578740456
# bpd (running average): 2.3681705924217336
# bpd (running average): 2.3684298231871646
# bpd (running average): 2.3681315210740834
# bpd (running average): 2.368708717299911
# bpd (running average): 2.3684740841232625
# bpd (running average): 2.3683261206114614
# bpd (running average): 2.36863623267989
# bpd (running average): 2.3680024369672164
# bpd (running average): 2.3679021994592633
# bpd (running average): 2.367702759555229
# bpd (running average): 2.3678910284515933
# bpd (running average): 2.367588100097676
# bpd (running average): 2.367023585365647
# bpd (running average): 2.366942166658275
# bpd (running average): 2.3675234501064635
# bpd (running average): 2.3676828919101247
# bpd (running average): 2.3677897818575224
# bpd (running average): 2.3678410422002476
# bpd (running average): 2.367631073049333
# bpd (running average): 2.3670154570809405
# bpd (running average): 2.366368594549288
# bpd (running average): 2.366596973810565
# bpd (running average): 2.366384834619087
# bpd (running average): 2.3659846744059223
# bpd (running average): 2.3659348717287556
# bpd (running average): 2.3649443161616825
# bpd (running average): 2.3649040718064374
# bpd (running average): 2.365625295492944
# bpd (running average): 2.366092143145561
# bpd (running average): 2.366603097623463
# bpd (running average): 2.3667919155100483
# bpd (running average): 2.3663400031940722
# bpd (running average): 2.365907035144757
# bpd (running average): 2.366177569302634
# bpd (running average): 2.3667500687259806
# bpd (running average): 2.367200569851835
# bpd (running average): 2.3672296566416295
# bpd (running average): 2.3668079052636926
# bpd (running average): 2.3673627983676795
# bpd (running average): 2.3680109655124917
# bpd (running average): 2.3683124073480073
# bpd (running average): 2.368908526884367
# bpd (running average): 2.3684662887463737
# bpd (running average): 2.3684887761123976
# bpd (running average): 2.3690143143911238
# bpd (running average): 2.368814685559458
# bpd (running average): 2.3687941472101524
# bpd (running average): 2.368832141572271
# bpd (running average): 2.3678725441457913
# bpd (running average): 2.367750036892811
# bpd (running average): 2.3677019846957
# bpd (running average): 2.3670404586711156
# bpd (running average): 2.367551531228601
# bpd (running average): 2.366733746463093
# bpd (running average): 2.3667348159568533
# bpd (running average): 2.3665036022212758
# bpd (running average): 2.3668018786817044
# bpd (running average): 2.366772160611297
# bpd (running average): 2.366671497999718
# bpd (running average): 2.36679755508325
# bpd (running average): 2.3671954036036444
# bpd (running average): 2.3672748660545055
# bpd (running average): 2.367776126574784
# bpd (running average): 2.3681688744210705
# bpd (running average): 2.3685292927750488
# bpd (running average): 2.3690622752521255
# bpd (running average): 2.3689397361994358
# bpd (running average): 2.368752919612564
# bpd (running average): 2.3687319569501013
# bpd (running average): 2.368289507167204
# bpd (running average): 2.3681794059811776
# bpd (running average): 2.368352598712582
# bpd (running average): 2.3684092412920585
# bpd (running average): 2.368222662956984
# bpd (running average): 2.3684887397659797
# bpd (running average): 2.368597278586182
# bpd (running average): 2.3689018366023227
# bpd (running average): 2.3686177048046853
# bpd (running average): 2.369214081936661
# bpd (running average): 2.368850716303603
# bpd (running average): 2.3683067892103034
# bpd (running average): 2.3675521757510873
# bpd (running average): 2.3680013572890135
# bpd (running average): 2.3682034370170872
# bpd (running average): 2.367284218538682
# bpd (running average): 2.3670107391948103
# bpd (running average): 2.3665422199804413
# bpd (running average): 2.3661482616311367
# bpd (running average): 2.3661704854743673
# bpd (running average): 2.3659496308552024
# bpd (running average): 2.3656992715921747
# bpd (running average): 2.3661980199740613
# bpd (running average): 2.365658273762572
# bpd (running average): 2.365997217781446
# bpd (running average): 2.36513260027513
# bpd (running average): 2.365215420205773
# bpd (running average): 2.365609674588657
# bpd (running average): 2.365008024382414
# bpd (running average): 2.3651046177579422
# bpd (running average): 2.3647848280107344
# bpd (running average): 2.3642953688681256
# bpd (running average): 2.364759772315719
# bpd (running average): 2.3653165365088507
# bpd (running average): 2.3657275591175355
# bpd (running average): 2.3658118952822718
# bpd (running average): 2.3659609108062827
# bpd (running average): 2.3656428809782377
# bpd (running average): 2.365718449840784
# bpd (running average): 2.3653640864181584
# bpd (running average): 2.3652139472496096
# bpd (running average): 2.3651964559135337
# bpd (running average): 2.3647849841576223
# bpd (running average): 2.3647754261118084
# bpd (running average): 2.365248345854664
# bpd (running average): 2.364862474925688
# bpd (running average): 2.3640853746061596
# bpd (running average): 2.3636820047365394
# bpd (running average): 2.3634032040548307
# bpd (running average): 2.363650255364343
# bpd (running average): 2.362950153551638
# bpd (running average): 2.363028271745586
# bpd (running average): 2.3629860736908053
# bpd (running average): 2.3634596371361365
# bpd (running average): 2.3635435025773868
# bpd (running average): 2.363528283337586
# bpd (running average): 2.3629695704243843
# bpd (running average): 2.362700060694605
# bpd (running average): 2.362426715326726
# bpd (running average): 2.3623321123270222
# bpd (running average): 2.3627470678020397
# bpd (running average): 2.3633647436692895
# bpd (running average): 2.3631884241774332
# bpd (running average): 2.3630010711038243
# bpd (running average): 2.3631008237471334
# bpd (running average): 2.3629985467504615
# bpd (running average): 2.363021402970089
# bpd (running average): 2.3633107743721844
# bpd (running average): 2.3632894701582767
# bpd (running average): 2.363105327377138
# bpd (running average): 2.3628838787026014
# bpd (running average): 2.3629986444578734
# bpd (running average): 2.362467083432049
# bpd (running average): 2.362321472536142
# bpd (running average): 2.3620943674255597
# bpd (running average): 2.361798669120838
# bpd (running average): 2.362030781704447
# bpd (running average): 2.361992770566847
# bpd (running average): 2.3619102187591037
# bpd (running average): 2.361785844479635
# bpd (running average): 2.3622563769189875
# bpd (running average): 2.362321989723459
# bpd (running average): 2.3626657475651514
# bpd (running average): 2.362596608602668
# bpd (running average): 2.3627312977253476
# bpd (running average): 2.3626725355076097
# bpd (running average): 2.3624123647886957
# bpd (running average): 2.361922780658357
# bpd (running average): 2.362144421016553
# bpd (running average): 2.3619058349465587
# bpd (running average): 2.361667817902627
# bpd (running average): 2.3611383082191058
# bpd (running average): 2.3610172138615577
# bpd (running average): 2.3608436154480734
# bpd (running average): 2.3609583823877527
# bpd (running average): 2.3612252271040117
# bpd (running average): 2.3615953813423984
# bpd (running average): 2.3615355888005243
# bpd (running average): 2.3614464507303623
# bpd (running average): 2.3613661804623205
# bpd (running average): 2.36103361407186
# bpd (running average): 2.361144363954304
# bpd (running average): 2.3613619107218153
# bpd (running average): 2.3613308511792193
# bpd (running average): 2.3615215210851708
# bpd (running average): 2.361418202557799
# bpd (running average): 2.361528920583412
# bpd (running average): 2.361582086538589
# bpd (running average): 2.3615675006944037
# bpd (running average): 2.3617009789073937
# bpd (running average): 2.3618747563930262
# bpd (running average): 2.3617780383775644
# bpd (running average): 2.3621675883730275
# bpd (running average): 2.362030590105542
# bpd (running average): 2.36213168407842
# bpd (running average): 2.362292992661819
# bpd (running average): 2.3622890090276223
# bpd (running average): 2.362529902270927
# bpd (running average): 2.3624936394250535
# bpd (running average): 2.3619301439382165
# bpd (running average): 2.3620654711328766
# bpd (running average): 2.362118470627871
# bpd (running average): 2.361945277551393
# bpd (running average): 2.3622692027363295
# bpd (running average): 2.361896069505042
# bpd (running average): 2.36165099737837
# bpd (running average): 2.3619953939796803
# bpd (running average): 2.3622642024707683
# bpd (running average): 2.3623985507134377
# bpd (running average): 2.3629259205090056
# bpd (running average): 2.3628632186405043
# bpd (running average): 2.3623143988521695
# bpd (running average): 2.362474136381123
# bpd (running average): 2.362796514256911
# bpd (running average): 2.3630632124324626
# bpd (running average): 2.3629817553858894
# bpd (running average): 2.3630472624494896
# bpd (running average): 2.3633017768861646
# bpd (running average): 2.362971520543053
# bpd (running average): 2.3631676523823204
# bpd (running average): 2.363309162247279
# bpd (running average): 2.363559767408553
# bpd (running average): 2.3638780428386106
# bpd (running average): 2.3645670060769914
# bpd (running average): 2.3647249544326256
# bpd (running average): 2.36474832717681
# bpd (running average): 2.364959291165644
# bpd (running average): 2.3646955503181615
# bpd (running average): 2.3643810488750945
# bpd (running average): 2.3644063904393295
# bpd (running average): 2.364203347400379
# bpd (running average): 2.3643734497022244
# bpd (running average): 2.3637659070148818
# bpd (running average): 2.3636622864174566
# bpd (running average): 2.363424836535313
# bpd (running average): 2.363199381277076
# bpd (running average): 2.363577018468117
# bpd (running average): 2.3638332191591926
# bpd (running average): 2.363942970758715
# bpd (running average): 2.3640632908266053
# bpd (running average): 2.364066398246507
# bpd (running average): 2.3639937145789576
# bpd (running average): 2.3644390342239126
# bpd (running average): 2.364344865453063
# bpd (running average): 2.3644029957046313
# bpd (running average): 2.3643725835144336
# bpd (running average): 2.364126623422506
# bpd (running average): 2.363802262443697
# bpd (running average): 2.363746687336601
# bpd (running average): 2.36357976237139
# bpd (running average): 2.3636836772492633
# bpd (running average): 2.363511099328607
# bpd (running average): 2.36338636529546
# bpd (running average): 2.363708645125421
# bpd (running average): 2.363783408675333
# bpd (running average): 2.3641372922337274
# bpd (running average): 2.363826887865451
# bpd (running average): 2.3637076169232962
# bpd (running average): 2.3641188296900855
# bpd (running average): 2.363954197228584
# bpd (running average): 2.36379539916356
# bpd (running average): 2.3634344501700633
# bpd (running average): 2.3635782049495013
# bpd (running average): 2.3637907684172323
# bpd (running average): 2.364114474931688
# bpd (running average): 2.364040770389474
# bpd (running average): 2.3640919028803027
# bpd (running average): 2.364734188391904
# bpd (running average): 2.3647808286928282
# bpd (running average): 2.3644934515232268
# bpd (running average): 2.3646859534967537
# bpd (running average): 2.365053700909847
# bpd (running average): 2.3651457673496914
# bpd (running average): 2.364984422739459
# bpd (running average): 2.364975969740652
# bpd (running average): 2.365059619062453
# bpd (running average): 2.365000162130669
# bpd (running average): 2.3648869548467633
# bpd (running average): 2.364804320112274
# bpd (running average): 2.364927667886875
# bpd (running average): 2.364824530549916
# bpd (running average): 2.364970451304394
# bpd (running average): 2.364797587099227
# bpd (running average): 2.3650175180466646
# bpd (running average): 2.364519557500524
# bpd (running average): 2.363871305301335
# bpd (running average): 2.3641429444852804
# bpd (running average): 2.364198745146481
# bpd (running average): 2.364325477115821
# bpd (running average): 2.364218949351438
# bpd (running average): 2.364730843583855
# bpd (running average): 2.3648318423315877
# bpd (running average): 2.364372737455743
# bpd (running average): 2.3647796079716974
# bpd (running average): 2.364908254033387
# bpd (running average): 2.3650360422368193
# bpd (running average): 2.3654772416462837
# bpd (running average): 2.3652334075143027
# bpd (running average): 2.3651363360066364
# bpd (running average): 2.3652366396840403
# bpd (running average): 2.365025724603284
# bpd (running average): 2.3650167444672796
# bpd (running average): 2.365031384125428
# bpd (running average): 2.365324798103595
# bpd (running average): 2.3655037067904474
# bpd (running average): 2.3655654485377338
# bpd (running average): 2.3653039005796113
# bpd (running average): 2.3652926821344487
# bpd (running average): 2.365091476677747
# bpd (running average): 2.364800601013177
# bpd (running average): 2.3646384395230933
# bpd (running average): 2.36463038983613
# bpd (running average): 2.3644186137506575
# bpd (running average): 2.3642006728776983
# bpd (running average): 2.3641821762558624
# bpd (running average): 2.3642408225758222
# bpd (running average): 2.364238130012953
# bpd (running average): 2.3638585086971964
# bpd (running average): 2.3638149429769406
# bpd (running average): 2.3637987406491128
# bpd (running average): 2.3637528690648617
# bpd (running average): 2.363779132135521
# bpd (running average): 2.3637810295282473
# bpd (running average): 2.363734802972682
# bpd (running average): 2.363968911643608
# bpd (running average): 2.363958685237291
# bpd (running average): 2.363799198271434
# bpd (running average): 2.363829159508684
# bpd (running average): 2.3640193737354958
# bpd (running average): 2.3642305874005953
# bpd (running average): 2.3637221510421043
# bpd (running average): 2.3640321984434416
# bpd (running average): 2.364314543637509
# bpd (running average): 2.3646220554342214
# bpd (running average): 2.3647340512298376
# bpd (running average): 2.3646934254937837
# bpd (running average): 2.364901995692305
# bpd (running average): 2.364972022754482
# bpd (running average): 2.3649221401806626
# bpd (running average): 2.364751833062702
# bpd (running average): 2.364861534917108
# bpd (running average): 2.36463510459728
# bpd (running average): 2.364315231136402
# bpd (running average): 2.3644653818867476
# bpd (running average): 2.3642516194189103
# bpd (running average): 2.3642455923339756
# bpd (running average): 2.3643827338758046
# bpd (running average): 2.364315411157606
# bpd (running average): 2.3642343616805976
# bpd (running average): 2.3644893566925136
# bpd (running average): 2.364637069258591
# bpd (running average): 2.3649043932944864
# bpd (running average): 2.364701902403751
# bpd (running average): 2.3645751309252314
# bpd (running average): 2.3646222149214258
# bpd (running average): 2.364485441290724
# bpd (running average): 2.3645084792671285
# bpd (running average): 2.3647003674973606
# bpd (running average): 2.3647600297088456
# bpd (running average): 2.3652025191579797
# bpd (running average): 2.36508077292758
# bpd (running average): 2.365233811265513
# bpd (running average): 2.365269052546142
# bpd (running average): 2.365352394499653
# bpd (running average): 2.3652644581549382
# bpd (running average): 2.3654468149827306
# bpd (running average): 2.365634150025243
# bpd (running average): 2.3654170309669134
# bpd (running average): 2.3650120853354046
# bpd (running average): 2.365256538872104
# bpd (running average): 2.3651775917737567
# bpd (running average): 2.365415083070168
# bpd (running average): 2.3655152158972803
# bpd (running average): 2.3655961238751995
# bpd (running average): 2.3656398218684727
# bpd (running average): 2.365600555028184
# bpd (running average): 2.365522813106773
# bpd (running average): 2.3653352400879477
# bpd (running average): 2.365789861949235
# bpd (running average): 2.365284490461241
# bpd (running average): 2.365366165966974
# bpd (running average): 2.365245922107843
# bpd (running average): 2.365061313824818
# bpd (running average): 2.3651290449503715
# bpd (running average): 2.3652528886559647
# bpd (running average): 2.3655901013907914
# bpd (running average): 2.365337970489055
# bpd (running average): 2.365287342284091
# bpd (running average): 2.3650635000781217
# bpd (running average): 2.364631438842316
# bpd (running average): 2.364968459324934
# bpd (running average): 2.365062664952718
# bpd (running average): 2.3652350370809376
# bpd (running average): 2.3652858489772575
# bpd (running average): 2.364915892421958
# bpd (running average): 2.3652037610608767
# bpd (running average): 2.365333699838017
# bpd (running average): 2.3655855152072482
# bpd (running average): 2.3658315287160763
# bpd (running average): 2.3660208852576794
# bpd (running average): 2.3661071616333182
# bpd (running average): 2.3658995623751484
# bpd (running average): 2.3661429788928987
# bpd (running average): 2.3664177511757045
# bpd (running average): 2.3663241563938335
# bpd (running average): 2.3664496553726377
# bpd (running average): 2.366342873057437
# bpd (running average): 2.366172294880454
# bpd (running average): 2.3660796341921637
# bpd (running average): 2.3659690707122225
# bpd (running average): 2.365951874136071
# bpd (running average): 2.3656601248191653
# bpd (running average): 2.3657354709849883
# bpd (running average): 2.365752881642446
# bpd (running average): 2.3657621609696173
# bpd (running average): 2.3656585744986076
# bpd (running average): 2.3656570046508616
# bpd (running average): 2.365621762001916
# bpd (running average): 2.3655780503917194
# bpd (running average): 2.3659041511141368
# bpd (running average): 2.366236348401281
# bpd (running average): 2.3662183123150426
# bpd (running average): 2.3663417843378682
# bpd (running average): 2.366056643120532
# bpd (running average): 2.3660647968104738
# bpd (running average): 2.365744098504031
# bpd (running average): 2.366039894420889
# bpd (running average): 2.366037450937135
# bpd (running average): 2.366079041717922
# bpd (running average): 2.3660833260364122
# bpd (running average): 2.366361797033244
# bpd (running average): 2.3663810283975653
# bpd (running average): 2.3664523771841783
# bpd (running average): 2.3665957334764705
# bpd (running average): 2.3666512519711045
# bpd (running average): 2.366257022872836
# bpd (running average): 2.366153585249229
# bpd (running average): 2.365768940421984
# bpd (running average): 2.365637957322628
# bpd (running average): 2.3656128317487024
# bpd (running average): 2.3655008165776645
# bpd (running average): 2.3654264851812377
# bpd (running average): 2.365623419692818
# bpd (running average): 2.3655558858039925
# bpd (running average): 2.365548732032864
# bpd (running average): 2.3654795050411233
# bpd (running average): 2.365571884167311
# bpd (running average): 2.365518832629385
# bpd (running average): 2.3655152676809448
# bpd (running average): 2.3655803747522004
# bpd (running average): 2.365709278663509
# bpd (running average): 2.365763224127247
# bpd (running average): 2.365785547640155
# bpd (running average): 2.3656027761149123
# bpd (running average): 2.365574128229974
# bpd (running average): 2.365360328030223
# bpd (running average): 2.365356368579666
# bpd (running average): 2.3653527963136067
# bpd (running average): 2.3651326764634053
# bpd (running average): 2.3652666762614647
# bpd (running average): 2.36576199431353
# bpd (running average): 2.365642919557685
# bpd (running average): 2.365627949215734
# bpd (running average): 2.365705533211811
# bpd (running average): 2.3654752633496976
# bpd (running average): 2.365575074291354
# bpd (running average): 2.3657241761938286
# bpd (running average): 2.365640819209623
# bpd (running average): 2.365433847487088
# bpd (running average): 2.3654474379099475
# bpd (running average): 2.3650653532955195
# bpd (running average): 2.36504329942179
# bpd (running average): 2.365303418405196
# bpd (running average): 2.3653613503380795
# bpd (running average): 2.3651398995565285
# bpd (running average): 2.36502862903982
# bpd (running average): 2.3652689766390433
# bpd (running average): 2.3650416981908453
# bpd (running average): 2.3649705259768803
# bpd (running average): 2.3651319026985624
# bpd (running average): 2.3650043248833956
# bpd (running average): 2.3650129436071405
# bpd (running average): 2.3651389628351986
# bpd (running average): 2.36497648334967
# bpd (running average): 2.3648336682224724
# bpd (running average): 2.364784355819298
# bpd (running average): 2.364693942990162
# bpd (running average): 2.364713876583648
# bpd (running average): 2.3649708773263924
# bpd (running average): 2.3650429583422348
# bpd (running average): 2.3648592594268134
# bpd (running average): 2.3650200042438243
# bpd (running average): 2.365193319573531
# bpd (running average): 2.3648625077980605
# bpd (running average): 2.364847669601503
# bpd (running average): 2.364844375128724
# bpd (running average): 2.364952376851361
# bpd (running average): 2.3649735329592847
# bpd (running average): 2.3650070887998664
# bpd (running average): 2.3649005827842324
# bpd (running average): 2.3650599412225852
# bpd (running average): 2.364912183938723
# bpd (running average): 2.364946909162965
# bpd (running average): 2.3647994571661077
# bpd (running average): 2.364721908172098
# bpd (running average): 2.364999873791338
# bpd (running average): 2.364891799879262
# bpd (running average): 2.3648784104067357
# bpd (running average): 2.3648002198069245
# bpd (running average): 2.364877430474129
# bpd (running average): 2.3648361530934916
# bpd (running average): 2.3649795845760084
# bpd (running average): 2.364896255346036
# bpd (running average): 2.3649779762045173
# bpd (running average): 2.3648182624163825
# bpd (running average): 2.3647717788883877
# bpd (running average): 2.3647878302415606
# bpd (running average): 2.3646837456575205
# bpd (running average): 2.364519801723716
# bpd (running average): 2.3644998929318337
# bpd (running average): 2.3644957233563675
# bpd (running average): 2.3644937407219215
# bpd (running average): 2.3641977376880274
# bpd (running average): 2.3641719442586764
# bpd (running average): 2.364144795279307
# bpd (running average): 2.3640147454254015
# bpd (running average): 2.3639224938691568
# bpd (running average): 2.3637025763713595
# bpd (running average): 2.3637987295713425
# bpd (running average): 2.3637356622888803
# bpd (running average): 2.3640579461257727
# bpd (running average): 2.3639677023926553
# bpd (running average): 2.3637801701331163
# bpd (running average): 2.363522592487163
# bpd (running average): 2.363589128227686
# bpd (running average): 2.363294401892782
# bpd (running average): 2.3633628437975243
# bpd (running average): 2.363276647617784
# bpd (running average): 2.3633010765119256
# bpd (running average): 2.363195354757472
# bpd (running average): 2.362949587898319
# bpd (running average): 2.3629656640929086
# bpd (running average): 2.3629467667119
# bpd (running average): 2.362818089939573
# bpd (running average): 2.362996053869345
# bpd (running average): 2.3632472705035723
# bpd (running average): 2.3637469502553206
# bpd (running average): 2.3640549128568633
# bpd (running average): 2.364426900121523
# bpd (running average): 2.364698439953422
# bpd (running average): 2.364674434019354
# bpd (running average): 2.36472698280726
# bpd (running average): 2.365045518381075
# bpd (running average): 2.3648714896136864
# bpd (running average): 2.3647162317507173
# bpd (running average): 2.3646745587599867
# bpd (running average): 2.3648020756792953
# bpd (running average): 2.365026784890883
# bpd (running average): 2.3651193883401453
# bpd (running average): 2.365233959367648
# bpd (running average): 2.3652649273164545
# bpd (running average): 2.3652413283707827
# bpd (running average): 2.3653663044370887
# bpd (running average): 2.3652684632599907
# bpd (running average): 2.365319536116887
# bpd (running average): 2.3654408184291555
# bpd (running average): 2.365493002533017
# bpd (running average): 2.365322206926587
# bpd (running average): 2.365345034254216
# bpd (running average): 2.3652567180821307
# bpd (running average): 2.3654067733196587
# bpd (running average): 2.3655217682012886
# bpd (running average): 2.365288130514837
# bpd (running average): 2.3651609962149647
# bpd (running average): 2.365159947550266
# bpd (running average): 2.3654109589080914
# bpd (running average): 2.3652027320751645
# bpd (running average): 2.3651844891873917
# bpd (running average): 2.3650377220089895
# bpd (running average): 2.3651866727415305
# bpd (running average): 2.3650731825091014
# bpd (running average): 2.3650907240816434
# bpd (running average): 2.3650416141580117
# bpd (running average): 2.365142294818751
# bpd (running average): 2.3652220609664636
# bpd (running average): 2.3652607116997135
# bpd (running average): 2.364983608128351
# bpd (running average): 2.3652256487268697
# bpd (running average): 2.365218435844754
# bpd (running average): 2.3649319966318147
# bpd (running average): 2.3649369688651536
# bpd (running average): 2.3646512215161564
# bpd (running average): 2.364828517939293
# bpd (running average): 2.364896547312699
# bpd (running average): 2.365054530031491
# bpd (running average): 2.3647533917910244
# bpd (running average): 2.3648603279696254
# bpd (running average): 2.364962220513774
# bpd (running average): 2.3648123094255054
# bpd (running average): 2.3650304828423026
# bpd (running average): 2.3650671252649906
# bpd (running average): 2.3651335173588266
# bpd (running average): 2.36509247438632
# bpd (running average): 2.365317633014215
# bpd (running average): 2.3652496327656016
# bpd (running average): 2.365341329496628
# bpd (running average): 2.3653988250832394
# bpd (running average): 2.36536812106155
# bpd (running average): 2.365219807656067
# bpd (running average): 2.365072308694604
# bpd (running average): 2.3651278807093195
# bpd (running average): 2.3649860830836356
# bpd (running average): 2.365055397483808
# bpd (running average): 2.364949711261929
# bpd (running average): 2.364999885874602
# bpd (running average): 2.3651454083152808
# bpd (running average): 2.365096391028219
# bpd (running average): 2.3652714752659856
# bpd (running average): 2.365286396666984
# bpd (running average): 2.3653764458743645
# bpd (running average): 2.365252541792488
# bpd (running average): 2.3653647611165503
# bpd (running average): 2.3654519389439415
# bpd (running average): 2.365339721737469
# bpd (running average): 2.365381583700745
# bpd (running average): 2.365380958021297
# bpd (running average): 2.365412167165519
# bpd (running average): 2.3654489243728047
# bpd (running average): 2.365462621294606
# bpd (running average): 2.365286975303891
# bpd (running average): 2.365264580572272
# bpd (running average): 2.3652274261063013
# bpd (running average): 2.3653101998665593
# bpd (running average): 2.365221638768198
# bpd (running average): 2.365122272267161
# bpd (running average): 2.3650284485102273
# bpd (running average): 2.3649928042660915
# bpd (running average): 2.3650755193460364
# bpd (running average): 2.365144973942033
# bpd (running average): 2.365328039687522
# bpd (running average): 2.365226268764792
# bpd (running average): 2.3652657803870043
# bpd (running average): 2.365562031130323
# bpd (running average): 2.365500637671428
# bpd (running average): 2.3654862754426165
# bpd (running average): 2.3654822883524282
# bpd (running average): 2.365604693061457
# bpd (running average): 2.365860080571418
# bpd (running average): 2.366092059689537
# bpd (running average): 2.3659000265569152
# bpd (running average): 2.3660307676342214
# bpd (running average): 2.366209414136795
# bpd (running average): 2.366164538152152
# bpd (running average): 2.3661432488433087
# bpd (running average): 2.365980472287448
# bpd (running average): 2.36604648248462
# bpd (running average): 2.36613206889344
# bpd (running average): 2.3662695241706673
# bpd (running average): 2.366357463405803
# bpd (running average): 2.3663269604057415
# bpd (running average): 2.366188476756169
# bpd (running average): 2.366144615119244
# bpd (running average): 2.366022984642344
# bpd (running average): 2.366243065830979
# bpd (running average): 2.36614355392977
# bpd (running average): 2.365880209687953
# bpd (running average): 2.365716640090475
# bpd (running average): 2.3658297374737276
# bpd (running average): 2.365753088616304
# bpd (running average): 2.3655347270289693
# bpd (running average): 2.365430593446812
# bpd (running average): 2.3656374284650465
# bpd (running average): 2.365761363776165
# bpd (running average): 2.3656133464381113
# bpd (running average): 2.3657793659617767
# bpd (running average): 2.3659746785501814
# bpd (running average): 2.3661637424422057
# bpd (running average): 2.366262622605264
# bpd (running average): 2.365998270296199
# bpd (running average): 2.3658852699766753
# bpd (running average): 2.36593698770226
# bpd (running average): 2.366127574782127
# bpd (running average): 2.365988933674503
# bpd (running average): 2.366094858617814
# bpd (running average): 2.3660665059751964
# bpd (running average): 2.3661176249116393
# bpd (running average): 2.3658257639321723
# bpd (running average): 2.3658350678760893
# bpd (running average): 2.365942377190923
# bpd (running average): 2.366020134337835
# bpd (running average): 2.3660864720759283
# bpd (running average): 2.36605501330591
# bpd (running average): 2.365851948245107
# bpd (running average): 2.3659063608853925
# bpd (running average): 2.3660017337588877
# bpd (running average): 2.3658679850803783
# bpd (running average): 2.3659677616663384
# bpd (running average): 2.3659372885101893
# bpd (running average): 2.3657428691351567
# bpd (running average): 2.365647136752686
# bpd (running average): 2.365716314983647
# bpd (running average): 2.3656959195579157
# bpd (running average): 2.3658627796503904
# bpd (running average): 2.365782260747617
# bpd (running average): 2.3657615122276434
# bpd (running average): 2.3659505143276944
# bpd (running average): 2.365892734902827
# bpd (running average): 2.3658509979610933
# bpd (running average): 2.365699717380523
# bpd (running average): 2.3655525415310716
# bpd (running average): 2.365316998479838
# bpd (running average): 2.3652393804107557
# bpd (running average): 2.365280827887268
# bpd (running average): 2.3652629126546927
# bpd (running average): 2.3651544107713027
# bpd (running average): 2.364912658998877
# bpd (running average): 2.3649048519148983
# bpd (running average): 2.3649340998233823
# bpd (running average): 2.365009468659903
# bpd (running average): 2.3648094035699447
# bpd (running average): 2.3647718888069886
# bpd (running average): 2.364680780181227
# bpd (running average): 2.364672181963073
# bpd (running average): 2.364866332781986
# bpd (running average): 2.3650466385327413
# bpd (running average): 2.3651176464327337
# bpd (running average): 2.364888563163317
# bpd (running average): 2.364933228536345
# bpd (running average): 2.36485734250032
# bpd (running average): 2.365087314661463
# bpd (running average): 2.36499411558974
# bpd (running average): 2.3649009439190682
# bpd (running average): 2.365047616155431
# bpd (running average): 2.3651867183367528
# bpd (running average): 2.364922223917239
# bpd (running average): 2.3648649058919613
# bpd (running average): 2.3651260769146587
# bpd (running average): 2.3652374244867285
# bpd (running average): 2.3652223725737263
# bpd (running average): 2.3653429396116374
# bpd (running average): 2.365166688774627
# bpd (running average): 2.365213960940853
# bpd (running average): 2.365284761618482
# bpd (running average): 2.365479850635456
# bpd (running average): 2.3656508838653445
# bpd (running average): 2.3656565616456255
# bpd (running average): 2.3656434633245187
# bpd (running average): 2.3658263035330056
# bpd (running average): 2.3658335575283274
# bpd (running average): 2.3659480672572317
# bpd (running average): 2.365831767949443
# bpd (running average): 2.365668359605129
# bpd (running average): 2.365714709650939
# bpd (running average): 2.365768682827548
# bpd (running average): 2.3658088445856236
# bpd (running average): 2.365917908827674
# bpd (running average): 2.366107649784996
# bpd (running average): 2.3660736728598972
# bpd (running average): 2.366187637714382
# bpd (running average): 2.3661356134066285
# bpd (running average): 2.3661727743494128
# bpd (running average): 2.3664480381615416
# bpd (running average): 2.3664418562210305
# bpd (running average): 2.3662516233455513
# bpd (running average): 2.366509397227826
# bpd (running average): 2.3665299055493865
# bpd (running average): 2.3664950951682964
# bpd (running average): 2.3663970447196125
# bpd (running average): 2.366432148725185
# bpd (running average): 2.36628925827606
# bpd (running average): 2.3662984681831363
# bpd (running average): 2.366408422892954
# bpd (running average): 2.36630297708383
# bpd (running average): 2.3665404069937663
# bpd (running average): 2.3664712904018974
# bpd (running average): 2.3666903561329335
# bpd (running average): 2.366683887620818
# bpd (running average): 2.3667076066093387
# bpd (running average): 2.3669142245100363
# bpd (running average): 2.367067905092717
# bpd (running average): 2.3670465185853975
# bpd (running average): 2.366957563812577
# bpd (running average): 2.3670822338173387
# bpd (running average): 2.3668802963839157
# bpd (running average): 2.366626014901623
# bpd (running average): 2.3667673122949333
# bpd (running average): 2.366661595577188
# bpd (running average): 2.366626945844312
# bpd (running average): 2.366688964353927
# bpd (running average): 2.3667236558174394
# bpd (running average): 2.3667851033924574
# bpd (running average): 2.3664318911284092
# bpd (running average): 2.3663954612474005
# bpd (running average): 2.3663942172593653
# bpd (running average): 2.3665180394839105
# bpd (running average): 2.366650313252398
# bpd (running average): 2.3667030071556487
# bpd (running average): 2.366764747504773
# bpd (running average): 2.3666767678564757
# bpd (running average): 2.366636930936762
# bpd (running average): 2.3666469041556217
# bpd (running average): 2.366628472006215
# bpd (running average): 2.3666300389616715
# bpd (running average): 2.3665907938099635
# bpd (running average): 2.3665755387866274
# bpd (running average): 2.366291044968144
# bpd (running average): 2.3661677368747505
# bpd (running average): 2.3663428283377987
# bpd (running average): 2.3661871599235917
# bpd (running average): 2.3660825745245897
# bpd (running average): 2.3661717589085582
# bpd (running average): 2.3661931002102845
# bpd (running average): 2.366091123834943
# bpd (running average): 2.3658232785140956
# bpd (running average): 2.365917536471889
# bpd (running average): 2.366021308666033
# bpd (running average): 2.3660476373851593
# bpd (running average): 2.36594071791636
# bpd (running average): 2.365802715678309
# bpd (running average): 2.3659467233486384
# bpd (running average): 2.3660342336185214
# bpd (running average): 2.365856325628447
# bpd (running average): 2.3659131784945324
# bpd (running average): 2.3660383014330595
# bpd (running average): 2.36588323385851
# bpd (running average): 2.365877614332313
# bpd (running average): 2.365988925694118
# bpd (running average): 2.3659350317370156
# bpd (running average): 2.3658072136948145
# bpd (running average): 2.365722210250752
# bpd (running average): 2.3659068614477574
# bpd (running average): 2.3661306121752257
# bpd (running average): 2.366021527744186
# bpd (running average): 2.365980657020074
# bpd (running average): 2.3662270765820193
# bpd (running average): 2.3662015387426547
# bpd (running average): 2.366291435356854
# bpd (running average): 2.3662677586607277
# bpd (running average): 2.366216443287367
# bpd (running average): 2.366096877698513
# ...
# bpd (running average): 2.3627116270829527
# bpd (running average): 2.36276314650486
# bpd (running average): 2.3627884353522415
# bpd (running average): 2.36266939269156
# bpd (running average): 2.3628183998556183
# bpd (running average): 2.3627559116568406
# bpd (running average): 2.362786192658856
# bpd (running average): 2.362719351288466
# bpd (running average): 2.362518973599578
# bpd (running average): 2.362597677078878
# bpd (running average): 2.3626807131989485
# bpd (running average): 2.362733434125597
# bpd (running average): 2.362824283669402
# bpd (running average): 2.3629031828747786
# bpd (running average): 2.3627443376360993
# bpd (running average): 2.362801426136894
# bpd (running average): 2.3627303087850433
# bpd (running average): 2.3626676653782717
# bpd (running average): 2.3627661660020762
# bpd (running average): 2.3626518454000176
# bpd (running average): 2.3626665831916034
# bpd (running average): 2.36253270169302
# bpd (running average): 2.3624627610894127
# bpd (running average): 2.362427280097878
# bpd (running average): 2.362378899849652
# bpd (running average): 2.3624521452969898
# bpd (running average): 2.3624149028698094
# bpd (running average): 2.3623646572932238
# bpd (running average): 2.3622242750817
# bpd (running average): 2.3621106538015977
# bpd (running average): 2.362121170655697
# bpd (running average): 2.362180876475855
# bpd (running average): 2.3621835308895824
# bpd (running average): 2.3620964019809993
# bpd (running average): 2.361912430540684
# bpd (running average): 2.3618940966743134
# bpd (running average): 2.3619012667810093
# bpd (running average): 2.361913833385386
# bpd (running average): 2.36195717983827
# bpd (running average): 2.3621141883893335
# bpd (running average): 2.3621169249463563
# bpd (running average): 2.362225278297797
# bpd (running average): 2.3621870488968195
# bpd (running average): 2.362231667628011
# bpd (running average): 2.3621837207066236
# bpd (running average): 2.3622423299648707
# bpd (running average): 2.362220919739269
# bpd (running average): 2.362259864049823
# bpd (running average): 2.362301731586816
# bpd (running average): 2.3621084820421374
# bpd (running average): 2.3621338062689095
# bpd (running average): 2.3619737513172914
# bpd (running average): 2.361778443527165
# bpd (running average): 2.3618433061866155
# bpd (running average): 2.3618329899086223
# bpd (running average): 2.361932843896397
# bpd (running average): 2.361991754705754
# bpd (running average): 2.361978902379386
# bpd (running average): 2.3620267417964405
# bpd (running average): 2.3620684254029176
# bpd (running average): 2.3620168744464825
# bpd (running average): 2.362019770623698
# bpd (running average): 2.3620187422043744
# bpd (running average): 2.362083861241137
# bpd (running average): 2.3620683696092395
# bpd (running average): 2.3619652017819934
# bpd (running average): 2.361946225359245
# bpd (running average): 2.3618880763861547
# bpd (running average): 2.361908144692198
# bpd (running average): 2.362072151238663
# bpd (running average): 2.3621381086275015
# bpd (running average): 2.362049532223405
# bpd (running average): 2.362047234341176
# bpd (running average): 2.362081203344548
# bpd (running average): 2.362178865200424
# bpd (running average): 2.362051096130736
# bpd (running average): 2.36184148904264
# bpd (running average): 2.361782100434794
# bpd (running average): 2.3617563772320485
# bpd (running average): 2.3618619771838403
# bpd (running average): 2.3618770161870124
# bpd (running average): 2.3617562995966117
# bpd (running average): 2.361732875961898
# bpd (running average): 2.361707395713867
# bpd (running average): 2.361802964893726
# bpd (running average): 2.3617005443788126
# bpd (running average): 2.361830473087508
# bpd (running average): 2.361791904376297
# bpd (running average): 2.3618959362801406
# bpd (running average): 2.361887119553772
# bpd (running average): 2.3619176803645403
# bpd (running average): 2.36184525211708
# bpd (running average): 2.3619870541274923
# bpd (running average): 2.362120751767859
# bpd (running average): 2.362068686254505
# bpd (running average): 2.3619996719313576
# bpd (running average): 2.3621089787540326
# bpd (running average): 2.3621740615902636
# bpd (running average): 2.362157335613951
# bpd (running average): 2.3621913031293666
# bpd (running average): 2.362232281056681
# bpd (running average): 2.3624898891519512
# bpd (running average): 2.3624900723983133
# bpd (running average): 2.3626377599458888
# bpd (running average): 2.3626074384584816
# bpd (running average): 2.3626627114326015
# bpd (running average): 2.3626902069337197
# bpd (running average): 2.3626946271985485
# bpd (running average): 2.3627472432880787
# bpd (running average): 2.3627003791053824
# bpd (running average): 2.3627344297568547
# bpd (running average): 2.3628626931778673
# bpd (running average): 2.3627961328414346
# bpd (running average): 2.3626737787888348
# bpd (running average): 2.362569844386915
# bpd (running average): 2.362529284915196
# bpd (running average): 2.3625131839129416
# bpd (running average): 2.36259838994376
# bpd (running average): 2.3625219140273677
# bpd (running average): 2.3624805048783157
# bpd (running average): 2.3624395306222086
# bpd (running average): 2.3623967501349292
# bpd (running average): 2.362400641445436
# bpd (running average): 2.3625064189080867
# bpd (running average): 2.362547309619452
# bpd (running average): 2.3625002351440663
# bpd (running average): 2.3625586999658115
# bpd (running average): 2.362630170693119
# bpd (running average): 2.362691292321017
# bpd (running average): 2.362686265442225
# bpd (running average): 2.3626329045022567
# bpd (running average): 2.36268078953314
# bpd (running average): 2.3626543457009355
# bpd (running average): 2.3626220879991138
# bpd (running average): 2.362560193229667
# bpd (running average): 2.3625363541054845
# bpd (running average): 2.362549508128996
# bpd (running average): 2.362498356442886
# bpd (running average): 2.3625125823183386
# bpd (running average): 2.3626198820290614
# bpd (running average): 2.3626266830150713
# bpd (running average): 2.3626463971176235
# bpd (running average): 2.362623321943445
# bpd (running average): 2.3626104676153807
# bpd (running average): 2.362671728632557
# bpd (running average): 2.3626688247803083
# bpd (running average): 2.3625718469214125
# bpd (running average): 2.3626030725003044
# bpd (running average): 2.3626324129829612
# bpd (running average): 2.3624269157927786
# bpd (running average): 2.36248280300856
# bpd (running average): 2.362445835910466
# bpd (running average): 2.3624444180066484
# bpd (running average): 2.3624936535728285
# bpd (running average): 2.362544182290242
# bpd (running average): 2.3626457831571535
# bpd (running average): 2.3628639131630877
# bpd (running average): 2.3627339559679084
# bpd (running average): 2.362719743396105
# bpd (running average): 2.362723858110414
# bpd (running average): 2.362721243244699
# bpd (running average): 2.362737137951449
# bpd (running average): 2.3628116520315734
# bpd (running average): 2.36286329918117
# bpd (running average): 2.362807841084621
# bpd (running average): 2.362910904321582
# bpd (running average): 2.3629615473705776
# bpd (running average): 2.363021017300276
# bpd (running average): 2.363087681302608
# bpd (running average): 2.363062769986923
# bpd (running average): 2.3629659095259368
# bpd (running average): 2.3630390003499135
# bpd (running average): 2.3630346059511984
# bpd (running average): 2.3631429912864244
# bpd (running average): 2.3631557685280042
# bpd (running average): 2.3630129272383056
# bpd (running average): 2.3629204540395783
# bpd (running average): 2.3628874832881395
# bpd (running average): 2.362727359635171
# bpd (running average): 2.36279536756178
# bpd (running average): 2.3627400624623998
# bpd (running average): 2.362862171314675
# bpd (running average): 2.3627946857461444
# bpd (running average): 2.36275311537328
# bpd (running average): 2.3627579674251202
# bpd (running average): 2.362645999846233
# bpd (running average): 2.362610024185249
# bpd (running average): 2.3625694991296338
# bpd (running average): 2.3626233534931633
# bpd (running average): 2.3625415044790015
# bpd (running average): 2.3625198202568765
# bpd (running average): 2.362395777765526
# bpd (running average): 2.362334912787087
# bpd (running average): 2.3624073235869507
# bpd (running average): 2.3624059395249972
# bpd (running average): 2.3624658220864214
# bpd (running average): 2.3623595168226084
# bpd (running average): 2.362307022219973
# bpd (running average): 2.3622051462357745
# bpd (running average): 2.362168125609839
# bpd (running average): 2.3621406425664735
# bpd (running average): 2.3620624335859373
# bpd (running average): 2.362045336548578
# bpd (running average): 2.3621189145005776
# bpd (running average): 2.362104294199442
# bpd (running average): 2.3621264550277457
# bpd (running average): 2.362080044285266
# bpd (running average): 2.3620322167253485
# bpd (running average): 2.3619459158243052
# bpd (running average): 2.362041060250982
# bpd (running average): 2.3620555515450965
# bpd (running average): 2.3619491665349766
# bpd (running average): 2.36173578240827
# bpd (running average): 2.361811177529446
# bpd (running average): 2.36177005209475
# bpd (running average): 2.3618702105734037
# bpd (running average): 2.3619553332573977
# bpd (running average): 2.3617258319626604
# bpd (running average): 2.3615736940218586
# bpd (running average): 2.3616043580615496
# bpd (running average): 2.3615956754726883
# bpd (running average): 2.361633151452802
# bpd (running average): 2.3616246788294437
# bpd (running average): 2.361580213504241
# bpd (running average): 2.3615966754905844
# bpd (running average): 2.3615640103237374
# bpd (running average): 2.361543224231887
# bpd (running average): 2.361503609596128
# bpd (running average): 2.3614531570896173
# bpd (running average): 2.3615554864569006
# bpd (running average): 2.3616138748347546
# bpd (running average): 2.361649224375765
# bpd (running average): 2.3616029494673403
# bpd (running average): 2.361538060352691
# bpd (running average): 2.361545886757158
# bpd (running average): 2.3614575824318775
# bpd (running average): 2.3614204398853103
# bpd (running average): 2.3615393478101607
# bpd (running average): 2.3616013666779256
# bpd (running average): 2.3616946619949726
# bpd (running average): 2.3616322445090936
# bpd (running average): 2.3616385938273345
# bpd (running average): 2.3616838641623703
# bpd (running average): 2.361617482207682
# bpd (running average): 2.361601393235508
# bpd (running average): 2.3615424958225506
# bpd (running average): 2.3615647209559905
# bpd (running average): 2.361535181015092
# bpd (running average): 2.3613714080645307
# bpd (running average): 2.3613681943056672
# bpd (running average): 2.3613596066182767
# bpd (running average): 2.3614093018642297
# bpd (running average): 2.361495321876329
# bpd (running average): 2.3616048520849278
# bpd (running average): 2.361491308234704
# bpd (running average): 2.3614081120766803
# bpd (running average): 2.361464283603665
# bpd (running average): 2.361394533707226
# bpd (running average): 2.361506751392134
# bpd (running average): 2.361412910722762
# bpd (running average): 2.3614574025300517
# bpd (running average): 2.3613685913790556
# bpd (running average): 2.3613199581065074
# bpd (running average): 2.361366189860526
# bpd (running average): 2.3615009878193907
# bpd (running average): 2.361528786428562
# bpd (running average): 2.361528823023212
# bpd (running average): 2.3614901263221855
# bpd (running average): 2.361465254979542
# bpd (running average): 2.3615548082866664
# bpd (running average): 2.361530261497981
# bpd (running average): 2.3615469247998124
# bpd (running average): 2.361487984947804
# bpd (running average): 2.361501130830529
# bpd (running average): 2.361358868826636
# bpd (running average): 2.3613407056098326
# bpd (running average): 2.3612492571421204
# bpd (running average): 2.361211375525098
# bpd (running average): 2.3611928776663498
# bpd (running average): 2.361132680393245
# bpd (running average): 2.36123929180402
# bpd (running average): 2.361270372952507
# bpd (running average): 2.3612596763535616
# bpd (running average): 2.3612348617144545
# bpd (running average): 2.3612497912317645
# bpd (running average): 2.3612717175614097
# bpd (running average): 2.361113754766266
# bpd (running average): 2.3611889407142814
# bpd (running average): 2.361149598575177
# bpd (running average): 2.361040521940236
# bpd (running average): 2.3610995001394506
# bpd (running average): 2.3611329577956948
# bpd (running average): 2.3611832967380724
# bpd (running average): 2.361135984114023
# bpd (running average): 2.361067206816779
# bpd (running average): 2.3611298272897527
# bpd (running average): 2.361120986604528
# bpd (running average): 2.361141421692943
# bpd (running average): 2.361019116318618
# bpd (running average): 2.3610002993141266
# bpd (running average): 2.3609797310759095
# bpd (running average): 2.360950146823398
# bpd (running average): 2.3609878529382446
# bpd (running average): 2.361026681649555
# bpd (running average): 2.3611752213168775
# bpd (running average): 2.3610778164117994
# bpd (running average): 2.3610904267148434
# bpd (running average): 2.361242453404805
# bpd (running average): 2.361199679796314
# bpd (running average): 2.361242626400746
# bpd (running average): 2.361151633069882
# bpd (running average): 2.361122177605833
# bpd (running average): 2.3611826320103946
# bpd (running average): 2.3611025755090234
# bpd (running average): 2.3610283712442035
# bpd (running average): 2.361043479301203
# bpd (running average): 2.3610802950209133
# bpd (running average): 2.361136328443632
# bpd (running average): 2.361047635449543
# bpd (running average): 2.3610284572678344
# bpd (running average): 2.360973063771237
# bpd (running average): 2.3609635486504783
# bpd (running average): 2.3610338209025596
# bpd (running average): 2.361196770546015
# bpd (running average): 2.361230998056804
# bpd (running average): 2.3612391981919107
# bpd (running average): 2.3614326998815693
# bpd (running average): 2.361472477153279
# bpd (running average): 2.361400221263462
# bpd (running average): 2.361454205417976
# bpd (running average): 2.3614384288142762
# bpd (running average): 2.361545106136052
# bpd (running average): 2.361564582639092
# bpd (running average): 2.3615016639156896
# bpd (running average): 2.3613535324747126
# bpd (running average): 2.3613289223750007
# bpd (running average): 2.3613865717841866
# bpd (running average): 2.3612271835674417
# bpd (running average): 2.361333029586796
# bpd (running average): 2.3613111153723096
# bpd (running average): 2.3612493389000853
# bpd (running average): 2.3613372176303358
# bpd (running average): 2.3613271579528643
# bpd (running average): 2.361406108388906
# bpd (running average): 2.3612665045692722
# bpd (running average): 2.361235666943914
# bpd (running average): 2.361375407957492
# bpd (running average): 2.361425199365454
# bpd (running average): 2.3615163115179456
# bpd (running average): 2.361456038218589
# bpd (running average): 2.361575198960409
# bpd (running average): 2.361536355499657
# bpd (running average): 2.361408813481515
# bpd (running average): 2.3614329279664545
# bpd (running average): 2.361438861212585
# bpd (running average): 2.3614488304335843
# bpd (running average): 2.361463797792161
# bpd (running average): 2.361304942651508
# bpd (running average): 2.3612566207542325
# bpd (running average): 2.3611524663519945
# bpd (running average): 2.361131143944234
# bpd (running average): 2.3610436382202713
# bpd (running average): 2.360992143691553
# bpd (running average): 2.3610582732233842
# bpd (running average): 2.361053008604749
# bpd (running average): 2.3610488872536504
# bpd (running average): 2.36104429719032
# bpd (running average): 2.3609575234246116
# bpd (running average): 2.361020971639772
# bpd (running average): 2.3610114095924843
# bpd (running average): 2.361027946302135
# bpd (running average): 2.3609713049885377
# bpd (running average): 2.3608462772655177
# bpd (running average): 2.360792059172147
# bpd (running average): 2.360851938071448
# bpd (running average): 2.36085187166714
# bpd (running average): 2.360879432523772
# bpd (running average): 2.3609218679685484
# bpd (running average): 2.3609530111739416
# bpd (running average): 2.3609876152157434
# bpd (running average): 2.3611335413056866
# bpd (running average): 2.3612590556285253
# bpd (running average): 2.3611646412519307
# bpd (running average): 2.3612093946925827
#
# bpd (full average): 2.3612093946925827

# %% [markdown]
# ## Further Resources
#
# If you're interested in learning more about score-based generative models, the following papers would be a good start:
#
# *   Yang Song, and Stefano Ermon. "[Generative modeling by estimating gradients of the data distribution.](https://arxiv.org/pdf/1907.05600.pdf)" Advances in Neural Information Processing Systems. 2019.
# *    Yang Song, and Stefano Ermon. "[Improved Techniques for Training Score-Based Generative Models.](https://arxiv.org/pdf/2006.09011.pdf)" Advances in Neural Information Processing Systems. 2020.
# * Jonathan Ho, Ajay Jain, and Pieter Abbeel. "[Denoising diffusion probabilistic models.](https://arxiv.org/pdf/2006.11239.pdf)" Advances in Neural Information Processing Systems. 2020.
